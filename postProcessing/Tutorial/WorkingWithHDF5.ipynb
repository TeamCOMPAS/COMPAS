# %% [markdown]
# # Introduction
#
# COMPAS simulations produce all output by default in the form of an [HDF5 file](https://www.hdfgroup.org/solutions/hdf5/), which is a compact and memory efficient, but non-human-readable data file format. In order to interact with these output files, we use the python module `h5py`.
#
# Within each file are a variety of HDF5 Groups, representing a specific common event in binary evolution, e.g Roche-Lobe Overflow or Supernovae. These are described throughout the post-processing jupyter notebooks.

# %% [markdown]
# ## Material
#
# ### [1. Producing HDF5 output:](#1.-Producing-HDF5-output)
# How to run default COMPAS and produce a simple output file.
#
#
# ### [2. Reading HDF5 files:](#2.-Reading-HDF5-files)
# The basics and syntax of loading an HDF5 file.
#
#
# ### [3. Rewriting HDF5 files:](#3.-Rewriting-HDF5-files)
# How to rewrite/reduce the HDF5 data.

# %% [markdown]
# ### For the following sections, you will need to have the following python packages installed.
# ### `numpy, h5py, pandas`

# %%
import os, sys    # for handling paths
import h5py as h5  #for handling data format

# Import COMPAS root and python script directories
compasRootDir = os.environ['COMPAS_ROOT_DIR'] 
tutorialDir = compasRootDir + '/postProcessing/Tutorial/'

# Import useful COMPAS scripts for later use
sys.path.append(compasRootDir + 'postProcessing/PythonScripts')
from printCompasDetails import printCompasDetails
import rewrite_H5

# %% [markdown]
# # 1. Producing HDF5 output
#
# ## Here we show an example of how to run a basic COMPAS simulation in order to produce output in an HDF5 format. To run COMPAS, you need to set the environment variable $COMPAS_ROOT_DIR to the top level COMPAS directory. Ensure that you have compiled COMPAS, and that there is a COMPAS executable. We will store the output in the Tutorial directory for easy access later on.
#
# ## For simplicity, we will run COMPAS on all default settings except for the number of binaries produced. Here, we will run 1k binaries, which is relatively small. Later, we will look at production of double compact objects (DCOs), but these objects are sufficiently rare that in order to study them, we will need to run a simulation of ~1M binaries, but this can take some time depending on your hardware resources.
#
# ### *Note:* It is required to have some COMPAS output to complete the rest of the post-processing notebooks, but if you already have an output file, you can skip this section.

# %%
# To run terminal commands in a jupyter notebook, prepend the command with an exclamation mark
# !COMPAS -n 1000 -o {tutorialDir}
# Out:
# COMPAS v02.24.02
# Compact Object Mergers: Population Astrophysics and Statistics
# by Team COMPAS (http://compas.science/index.html)
# A binary star simulator
#
# Start generating binaries at Fri Nov  5 21:18:00 2021
#
# 0: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 1: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 2: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 3: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 4: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 5: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 6: Stars merged: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 7: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 8: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 9: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 10: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 11: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 12: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 13: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 14: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 15: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 16: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 17: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 18: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 19: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 20: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 21: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 22: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 23: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 24: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 25: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 26: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 27: Stars merged: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 28: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 29: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 30: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 31: Stars merged: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 32: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 33: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 34: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 35: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 36: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 37: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 38: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 39: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 40: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 41: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 42: Stars merged: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 43: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 44: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 45: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 46: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 47: Double White Dwarf: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 48: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 49: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 50: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 51: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 52: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 53: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 54: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 55: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 56: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 57: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 58: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 59: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 60: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 61: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 62: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 63: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 64: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 65: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 66: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 67: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 68: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 69: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 70: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 71: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 72: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 73: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 74: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 75: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 76: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 77: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 78: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 79: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 80: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 81: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 82: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 83: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 84: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 85: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 86: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 87: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 88: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 89: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 90: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 91: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 92: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 93: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 94: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 95: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 96: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 97: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 98: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 99: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 100: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 101: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 102: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 103: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 104: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 105: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 106: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 107: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 108: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 109: Double White Dwarf: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 110: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 111: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 112: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 113: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 114: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# Evolution of current binary stopped: Double compact object
# 115: Evolution stopped: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Black_Hole)
# 116: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 117: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 118: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 119: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 120: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 121: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 122: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 123: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 124: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 125: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 126: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 127: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 128: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 129: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# Evolution of current binary stopped: Double compact object
# 130: Evolution stopped: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Black_Hole)
# 131: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 132: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 133: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 134: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 135: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 136: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 137: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 138: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 139: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 140: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 141: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 142: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 143: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 144: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 145: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 146: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 147: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 148: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 149: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 150: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 151: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 152: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 153: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 154: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 155: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 156: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 157: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 158: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 159: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 160: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 161: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 162: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 163: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 164: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 165: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 166: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 167: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 168: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 169: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 170: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 171: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 172: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 173: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 174: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 175: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 176: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 177: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 178: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 179: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 180: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 181: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 182: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 183: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 184: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 185: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 186: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 187: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 188: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 189: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 190: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 191: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 192: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# Evolution of current binary stopped: Double compact object
# 193: Evolution stopped: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 194: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 195: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 196: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 197: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 198: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 199: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 200: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 201: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 202: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 203: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 204: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 205: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 206: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 207: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 208: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 209: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 210: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 211: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 212: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 213: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 214: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 215: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 216: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 217: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 218: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 219: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 220: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 221: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 222: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 223: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# Evolution of current binary stopped: Double compact object
# 224: Evolution stopped: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 225: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 226: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 227: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 228: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 229: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 230: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 231: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 232: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 233: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 234: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 235: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 236: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 237: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 238: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 239: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 240: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 241: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 242: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 243: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 244: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 245: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 246: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 247: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 248: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 249: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 250: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 251: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 252: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 253: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 254: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 255: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 256: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 257: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 258: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 259: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 260: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 261: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 262: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 263: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 264: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 265: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 266: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 267: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 268: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 269: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 270: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 271: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 272: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 273: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 274: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 275: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 276: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 277: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 278: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 279: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 280: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 281: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 282: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 283: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 284: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 285: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 286: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 287: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 288: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 289: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 290: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 291: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 292: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 293: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 294: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 295: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 296: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 297: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 298: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 299: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 300: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 301: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 302: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 303: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 304: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 305: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 306: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 307: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 308: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 309: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 310: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 311: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 312: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 313: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 314: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 315: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 316: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 317: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 318: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 319: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 320: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 321: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 322: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 323: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 324: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 325: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 326: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 327: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 328: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 329: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 330: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 331: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 332: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 333: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 334: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 335: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 336: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 337: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 338: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 339: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 340: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 341: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 342: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 343: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 344: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 345: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 346: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 347: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 348: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 349: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 350: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 351: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 352: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 353: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 354: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 355: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 356: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 357: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 358: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 359: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 360: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 361: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 362: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 363: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Hertzsprung_Gap)
# 364: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 365: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 366: Allowed time exceeded: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 367: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 368: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 369: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 370: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 371: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 372: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 373: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 374: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 375: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 376: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 377: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 378: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 379: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 380: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 381: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 382: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 383: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 384: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 385: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 386: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 387: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 388: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 389: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 390: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 391: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 392: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 393: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 394: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 395: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 396: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 397: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 398: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 399: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 400: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 401: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 402: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 403: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 404: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 405: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 406: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 407: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 408: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 409: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 410: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 411: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 412: Stars merged: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 413: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 414: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# ...
# 862: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 863: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 864: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 865: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap)
# 866: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 867: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 868: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 869: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 870: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 871: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 872: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 873: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 874: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 875: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 876: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 877: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 878: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 879: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 880: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 881: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 882: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 883: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 884: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 885: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 886: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 887: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 888: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 889: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 890: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 891: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 892: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 893: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 894: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 895: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 896: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 897: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 898: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 899: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 900: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 901: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 902: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 903: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 904: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 905: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 906: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 907: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 908: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 909: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 910: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 911: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 912: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 913: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 914: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 915: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 916: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 917: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 918: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 919: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 920: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 921: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 922: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 923: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 924: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 925: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 926: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 927: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 928: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 929: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 930: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 931: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 932: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 933: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 934: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 935: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 936: Stars merged: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 937: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 938: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 939: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 940: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 941: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 942: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 943: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 944: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 945: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 946: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 947: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 948: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 949: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 950: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 951: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 952: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 953: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 954: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 955: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 956: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 957: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 958: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 959: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 960: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 961: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 962: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 963: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 964: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 965: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 966: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 967: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 968: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 969: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 970: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 971: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 972: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 973: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 974: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 975: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 976: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 977: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 978: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 979: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 980: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 981: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 982: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 983: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 984: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 985: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 986: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 987: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 988: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 989: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 990: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 991: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 992: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 993: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 994: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 995: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 996: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 997: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 998: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 999: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
#
# Generated 1000 of 1000 binaries requested
#
# Simulation completed
#
# End generating binaries at Fri Nov  5 21:18:19 2021
#
# Clock time = 19.1541 CPU seconds
# Wall time  = 0000:00:19 (hhhh:mm:ss)

# %% [markdown]
# ### *Note:* This will produce output in the COMPAS_Output directory only the first time it is run. If you run this multiple times, new directories will be created as COMPAS_Output_X. Ensure that you are using the data in the desired directory.

# %% [markdown]
# ## Non-default settings can be seen by running the following in the command line

# %%
# !COMPAS --help
# Out:
# COMPAS v02.24.02
# Compact Object Mergers: Population Astrophysics and Statistics
# by Team COMPAS (http://compas.science/index.html)
# A binary star simulator
#
# Options:
# --PISN-lower-limit
#   Minimum core mass for PISN, in Msol (default = 60.000000)
# --PISN-upper-limit
#   Maximum core mass for PISN, in Msol (default = 135.000000)
# --PPI-lower-limit
#   Minimum core mass for PPI, in Msol (default = 35.000000)
# --PPI-upper-limit
#   Maximum core mass for PPI, in Msol (default = 60.000000)
# --add-options-to-sysparms
#   Add program options columns to BSE/SSE SysParms file (options: [ALWAYS, GRID, NEVER], default = GRID)
# --allow-rlof-at-birth
#   Allow binaries that have one or both stars in RLOF at birth to evolve (default = TRUE)
# --allow-touching-at-birth
#   Allow binaries that are touching at birth to evolve (default = FALSE)
# --angular-momentum-conservation-during-circularisation
#   Conserve angular momentum when binary is circularised when entering a Mass Transfer episode (default = FALSE)
# --black-hole-kicks
#   Black hole kicks relative to NS kicks (options: [FULL, REDUCED, ZERO, FALLBACK], default = FALLBACK)
# --case-BB-stability-prescription
#   Case BB/BC mass transfer stability prescription (options: [ALWAYS_STABLE, ALWAYS_STABLE_ONTO_NSBH, TREAT_AS_OTHER_MT, ALWAYS_UNSTABLE], default = ALWAYS_STABLE)
# --check-photon-tiring-limit
#   Check the photon tiring limit hasn't been exceeded by wind mass loss (default = FALSE)
# --chemically-homogeneous-evolution
#   Chemically Homogeneous Evolution (options: [NONE, OPTIMISTIC, PESSIMISTIC], default = PESSIMISTIC)
# --circularise-binary-during-mass-transfer
#   Circularise binary when it enters a Mass Transfer episode (default = TRUE)
# --common-envelope-allow-main-sequence-survive
#   Allow main sequence stars to survive common envelope evolution (default = TRUE)
# --common-envelope-alpha
#   Common Envelope efficiency alpha (default = 1.000000)
# --common-envelope-alpha-thermal
#   Defined such that lambda = alpha_th * lambda_b + (1.0 - alpha_th) * lambda_g (default = 1.000000)
# --common-envelope-lambda
#   Common Envelope lambda (default = 0.100000)
# --common-envelope-lambda-multiplier
#   Multiply lambda by some constant (default = 1.000000)
# --common-envelope-lambda-prescription
#   CE lambda prescription (options: [LAMBDA_FIXED, LAMBDA_LOVERIDGE, LAMBDA_NANJING, LAMBDA_KRUCKOW, LAMBDA_DEWI], default = LAMBDA_NANJING)
# --common-envelope-mass-accretion-constant
#   Value of mass accreted by NS/BH, in Msol, during common envelope evolution, assuming all NS/BH accrete same amount of mass (common-envelope-mass-accretion-prescription CONSTANT). Ignored otherwise (default = 0.000000)
# --common-envelope-mass-accretion-max
#   Maximum amount of mass accreted by NS/BHs, in Msol, during common envelope evolution in Msol (default = 0.100000)
# --common-envelope-mass-accretion-min
#   Minimum amount of mass accreted by NS/BHs, in Msol, during common envelope evolution in Msol (default = 0.040000)
# --common-envelope-mass-accretion-prescription
#   Assumption about whether NS/BHs can accrete mass during common envelope evolution (options: [ZERO, CONSTANT, UNIFORM, MACLEOD], default = ZERO)
# --common-envelope-recombination-energy-density
#   Recombination energy density, in erg/g (default = 15000000000000.000000)
# --common-envelope-slope-kruckow
#   Common Envelope slope for Kruckow lambda (default = -0.833333)
# --cool-wind-mass-loss-multiplier
#   Multiplicative constant for wind mass loss of cool stars (default = 1.000000)
# --debug-classes
#   Debug classes enabled (default = )
# --debug-level
#   Determines which print statements are displayed for debugging (default = 0)
# --debug-to-file
#   Write debug statements to file (default = FALSE)
# --detailed-output
#   Print detailed output to file (default = FALSE)
# --eccentricity [ -e ]
#   Eccentricity, e (default = 0.000000)
# --eccentricity-distribution
#   Initial eccentricity distribution (options: [ZERO, FLAT, THERMAL, GELLER+2013, DUQUENNOYMAYOR1991, SANA2012], default = ZERO)
# --eccentricity-max
#   Maximum eccentricity to generate (default = 1.000000)
# --eccentricity-min
#   Minimum eccentricity to generate (default = 0.000000)
# --eddington-accretion-factor
#   Multiplication factor for eddington accretion for NS & BH, i.e. >1 is super-eddington and 0. is no accretion (default = 1.000000)
# --enable-warnings
#   Display warning messages to stdout (default = FALSE)
# --envelope-state-prescription
#   Prescription for whether the envelope is radiative or convective (options: [LEGACY, HURLEY, FIXED_TEMPERATURE], default = LEGACY)
# --errors-to-file
#   Write error messages to file (default = FALSE)
# --evolve-pulsars
#   Evolve pulsars (default = FALSE)
# --evolve-unbound-systems
#   Continue evolving stars even if the binary is disrupted (default = FALSE)
# --fix-dimensionless-kick-magnitude
#   Fix dimensionless kick magnitude uk to this value (default = -1.000000, -ve values false, +ve values true)
# --fryer-supernova-engine
#   If using Fryer et al 2012 fallback prescription. (options: [DELAYED, RAPID], default = DELAYED)
# --grid
#   Grid filename (default = )
# --grid-lines-to-process
#   Specifies how many grid lines should be processed (from the start line - see grid-start-line) (default = Process to EOF)
# --grid-start-line
#   Specifies which line of the grid file is processed first (0-based) (default = 0)
# --hdf5-buffer-size
#   HDF5 file dataset IO buffer size (number of chunks, default = 1)
# --hdf5-chunk-size
#   HDF5 file dataset chunk size (number of dataset entries, default = 100000)
# --help [ -h ]
#   Print this help message
# --initial-mass
#   Initial mass (in Msol) for the star (SSE) (default = 5.000000)
# --initial-mass-1
#   Initial mass (in Msol) for the primary star (BSE) (default = 5.000000)
# --initial-mass-2
#   Initial mass (in Msol) for the secondary star (BSE) (default = 5.000000)
# --initial-mass-function [ -i ]
#   Initial mass function (options: [SALPETER, POWERLAW, UNIFORM, KROUPA], default = KROUPA)
# --initial-mass-max
#   Maximum mass (in Msol) to generate using given IMF (default = 150.000000)
# --initial-mass-min
#   Minimum mass (in Msol) to generate using given IMF (default = 5.000000)
# --initial-mass-power
#   Single power law power to generate primary mass using POWERLAW IMF (default = 0.000000)
# --kick-direction
#   Natal kick direction distribution (options: [ISOTROPIC, INPLANE, PERPENDICULAR, POWERLAW, WEDGE, POLES], default = ISOTROPIC)
# --kick-direction-power
#   Power for power law kick direction distribution (default = 0.000000 = isotropic, +ve = polar, -ve = in plane)
# --kick-magnitude
#   The magnitude of the kick velocity, in km/s, that the star receives during the a supernova (default = 0.000000)
# --kick-magnitude-1
#   The magnitude of the kick velocity, in km/s, that the primary star receives during the a supernova (default = 0.000000)
# --kick-magnitude-2
#   The magnitude of the kick velocity, in km/s, that the secondary star receives during the a supernova (default = 0.000000)
# --kick-magnitude-distribution
#   Natal kick magnitude distribution (options: [ZERO, FIXED, FLAT, MAXWELLIAN, BRAYELDRIDGE, MULLER2016, MULLER2016MAXWELLIAN, MULLERMANDEL], default = MAXWELLIAN)
# --kick-magnitude-max
#   Maximum drawn kick magnitude in km/s. Ignored if < 0. Must be > 0 if using kick-magnitude-distribution=FLAT (default = -1.000000)
# --kick-magnitude-random
#   Number used to choose the kick velocity magnitude for the star during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-random-1
#   Number used to choose the kick velocity magnitude for the primary star during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-random-2
#   Number used to choose the kick velocity magnitude for the secondary during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-sigma-CCSN-BH
#   Sigma for chosen kick magnitude distribution, in km/s, for black holes (default = 265.000000)
# --kick-magnitude-sigma-CCSN-NS
#   Sigma for chosen kick magnitude distribution, in km/s, for neutron stars (default = 265.000000)
# --kick-magnitude-sigma-ECSN
#   Sigma for chosen kick magnitude distribution, in km/s, for ECSN (default = 30.000000)
# --kick-magnitude-sigma-USSN
#   Sigma for chosen kick magnitude distribution, in km/s, for USSN (default = 30.000000)
# --kick-mean-anomaly-1
#   Mean anomaly, in rad, for the primary star at instantaneous time of the supernova (default = uniform random number [0.0, 2pi))
# --kick-mean-anomaly-2
#   Mean anomaly, in rad, for the secondary star at instantaneous time of the supernova (default = uniform random number [0.0, 2pi))
# --kick-phi-1
#   Planar angle, in rad, of the supernova vector, for the primary star (default = drawn from kick direction distribution)
# --kick-phi-2
#   Planar angle, in rad, of the supernova vector, for the secondary star (default = drawn from kick direction distribution)
# --kick-scaling-factor
#   Arbitrary factor used to scale kicks (default = 1.000000)
# --kick-theta-1
#   Polar angle, in rad, of the supernova vector, for the primary star (default = drawn from kick direction distribution)
# --kick-theta-2
#   Polar angle, in rad, of the supernova vector, for the secondary star (default = drawn from kick direction distribution)
# --log-classes
#   Logging classes enabled (default = )
# --log-level
#   Determines which print statements are included in the logfile (default = 0)
# --logfile-common-envelopes
#   Filename for BSE Common Envelopes logfile (default = BSE_Common_Envelopes)
# --logfile-definitions
#   Filename for logfile record definitions (default = )
# --logfile-detailed-output
#   Filename for BSE Detailed Output logfile (default = BSE_Detailed_Output)
# --logfile-double-compact-objects
#   Filename for Double Compact Objects logfile (default = BSE_Double_Compact_Objects)
# --logfile-name-prefix
#   Prefix for logfile names (default = )
# --logfile-pulsar-evolution
#   Filename for Pulsar Evolution logfile (default = BSE_Pulsar_Evolution)
# --logfile-rlof-parameters
#   Filename for BSE RLOF Parameters logfile ( default = BSE_RLOF)
# --logfile-supernovae
#   Filename for Supernovae logfile (default = BSE_Supernovae)
# --logfile-switch-log
#   Filename for Switch Log logfile (default = BSE_Switch_Log)
# --logfile-system-parameters
#   Filename for System Parameters logfile (default = BSE_System_Parameters)
# --logfile-type
#   File type for logfiles (options: [HDF5, CSV, TSV, TXT], default = HDF5)
# --luminous-blue-variable-multiplier
#   Multiplicitive constant for LBV mass loss (default = 1.500000, use 10 for Mennekens & Vanbeveren 2014)
# --luminous-blue-variable-prescription
#   LBV Mass loss prescription (options: [NONE, HURLEY_ADD, HURLEY, BELCZYNSKI], default = HURLEY_ADD)
# --mass-loss-prescription
#   Mass loss prescription (options: [NONE, HURLEY, VINK], default = VINK)
# --mass-ratio [ -q ]
#   Mass ratio m2/m1 used to determine secondary mass if not specified (default = 1.000000)
# --mass-ratio-distribution
#   Initial mass ratio distribution for q=m2/m1 (options: [FLAT, DUQUENNOYMAYOR1991, SANA2012], default = FLAT)
# --mass-ratio-max
#   Maximum mass ratio m2/m1 to generate (default = 1.000000)
# --mass-ratio-min
#   Minimum mass ratio m2/m1 to generate (default = 0.010000)
# --mass-transfer
#   Enable mass transfer (default = TRUE)
# --mass-transfer-accretion-efficiency-prescription
#   Mass Transfer Accretion Efficiency prescription (options: [THERMAL, FIXED], default = THERMAL)
# --mass-transfer-angular-momentum-loss-prescription
#   Mass Transfer Angular Momentum Loss prescription (options: [JEANS, ISOTROPIC, CIRCUMBINARY, ARBITRARY], default = ISOTROPIC)
# --mass-transfer-fa
#   Mass Transfer fraction accreted in FIXED prescription (default = 0.500000, fully conservative)
# --mass-transfer-jloss
#   Fraction of specific angular momentum which non-accreted matter removes from the system (default = 1.000000)
# --mass-transfer-rejuvenation-prescription
#   Mass Transfer Rejuvenation prescription (options: [NONE, STARTRACK], default = STARTRACK)
# --mass-transfer-thermal-limit-C
#   Mass Transfer Thermal rate factor of the accretor (default = 10.000000)
# --mass-transfer-thermal-limit-accretor
#   Mass Transfer Thermal Accretion limit (options: [CFACTOR, ROCHELOBE], default = CFACTOR)
# --maximum-evolution-time
#   Maximum time to evolve binaries, in Myr (default = 13700.000000)
# --maximum-mass-donor-nandez-ivanova
#   Maximum donor mass, in Msol, allowed for the revised common envelope formalism in Msol (default = 2.000000)
# --maximum-neutron-star-mass
#   Maximum mass of a neutron star, in Msol (default = 2.500000)
# --maximum-number-timestep-iterations
#   Maximum number of timesteps to evolve binary before giving up (default = 99999)
# --mcbur1
#   Minimum core mass at BAGB, in Msol, to avoid fully degenerate CO core  (default = 1.600000)
# --metallicity [ -z ]
#   Metallicity to use (default 0.014200)
# --metallicity-distribution
#   Metallicity distribution (options: [ZSOLAR, LOGUNIFORM], default = ZSOLAR)
# --metallicity-max
#   Maximum metallicity to generate (default = 0.030000)
# --metallicity-min
#   Minimum metallicity to generate (default = 0.000100)
# --minimum-secondary-mass
#   Minimum mass of secondary to generate, in Msol (default = 0.100000)
# --mode
#   Evolution mode (options: [SSE, BSE], default = BSE)
# --muller-mandel-kick-multiplier-BH
#   Scaling prefactor for BH kicks when using the 'MULLERMANDEL' kick magnitude distribution (default = 200.000000)
# --muller-mandel-kick-multiplier-NS
#   Scaling prefactor for NS kicks when using the 'MULLERMANDEL' kick magnitude distribution (default = 400.000000)
# --neutrino-mass-loss-BH-formation
#   Assumption about neutrino mass loss during BH formation (options: [FIXED_FRACTION, FIXED_MASS], default = FIXED_MASS)
# --neutrino-mass-loss-BH-formation-value
#   Amount of BH mass lost due to neutrinos (either fraction or fixed value, depending on --neutrino-mass-loss-BH-formation) (default = 0.100000)
# --neutron-star-equation-of-state
#   Neutron star equation of state to use (options: [SSE, ARP3], default = SSE)
# --number-of-systems [ -n ]
#   Specify the number of systems to simulate (SSE) (default = 10)
# --orbital-period
#   Initial orbital period, in days (default = 0.100000)
# --orbital-period-distribution
#   Initial orbital period distribution (options: [FLATINLOG], default = FLATINLOG)
# --orbital-period-max
#   Maximum period, in days, to generate (default = 1000.000000)
# --orbital-period-min
#   Minimum period, in days, to generate (default = 1.100000)
# --output-container [ -c ]
#   Container (directory) name for output files (default = COMPAS_Output)
# --output-path [ -o ]
#   Directory for output (default = .)
# --overall-wind-mass-loss-multiplier
#   Multiplicitive constant for overall wind mass loss (default = 1.000000)
# --pair-instability-supernovae
#   Enable pair instability supernovae (PISN) (default = TRUE)
# --population-data-printing
#   Print details of population (default = FALSE)
# --print-bool-as-string
#   Print boolean properties as 'TRUE' or 'FALSE' (default = FALSE)
# --pulsar-birth-magnetic-field-distribution
#   Pulsar Birth Magnetic Field distribution (options: [ZERO, FIXED, FLATINLOG, UNIFORM, LOGNORMAL], default = ZERO)
# --pulsar-birth-magnetic-field-distribution-max
#   Maximum pulsar birth magnetic field, in log10(Gauss) (default = 13.000000)
# --pulsar-birth-magnetic-field-distribution-min
#   Minimum pulsar birth magnetic field, in log10(Gauss) (default = 11.000000)
# --pulsar-birth-spin-period-distribution
#   Pulsar Birth Spin Period distribution (options: [ZERO, FIXED, UNIFORM, NORMAL], default = ZERO)
# --pulsar-birth-spin-period-distribution-max
#   Maximum pulsar birth spin period, in ms (default = 100.000000)
# --pulsar-birth-spin-period-distribution-min
#   Minimum pulsar birth spin period, in ms (default = 10.000000)
# --pulsar-magnetic-field-decay-massscale
#   Mass scale on which magnetic field decays during accretion, in Msol (default = 0.025000)
# --pulsar-magnetic-field-decay-timescale
#   Timescale on which magnetic field decays, in Myrs (default = 1000.000000)
# --pulsar-minimum-magnetic-field
#   Minimum pulsar magnetic field, in log10(Gauss) (default = 8.000000)
# --pulsational-pair-instability
#   Enable mass loss due to pulsational-pair-instability (PPI) (default = TRUE)
# --pulsational-pair-instability-prescription
#   Pulsational Pair Instability prescription (options: [COMPAS, STARTRACK, MARCHANT, FARMER], default = MARCHANT)
# --quiet
#   Suppress printing (default = FALSE)
# --random-seed
#   Random seed to use (default = 0)
# --remnant-mass-prescription
#   Choose remnant mass prescription (options: [HURLEY2000, BELCZYNSKI2002, FRYER2012, MULLER2016, MULLERMANDEL, SCHNEIDER2020, SCHNEIDER2020ALT], default = FRYER2012)
# --revised-energy-formalism-nandez-ivanova
#   Enable revised energy formalism (default = FALSE)
# --rlof-printing
#   Enable output parameters before/after RLOF (default = TRUE)
# --rotational-frequency
#   Initial rotational frequency for the star for SSE (Hz) (default = 0.000000)
# --rotational-frequency-1
#   Initial rotational frequency for the primary star for BSE (Hz) (default = 0.000000)
# --rotational-frequency-2
#   Initial rotational frequency for the secondary star for BSE (Hz) (default = 0.000000)
# --rotational-velocity-distribution
#   Initial rotational velocity distribution (options: [ZERO, HURLEY, VLTFLAMES], default = ZERO)
# --semi-major-axis [ -a ]
#   Initial semi-major axis, in AU (default = 0.100000)
# --semi-major-axis-distribution
#   Initial semi-major axis distribution (options: [FLATINLOG, CUSTOM, DUQUENNOYMAYOR1991, SANA2012], default = FLATINLOG)
# --semi-major-axis-max
#   Maximum semi-major axis, in AU, to generate (default = 1000.000000)
# --semi-major-axis-min
#   Minimum semi-major axis, in AU, to generate (default = 0.010000)
# --stellar-zeta-prescription
#   Prescription for stellar zeta (default = SOBERMAN)
# --store-input-files
#   Store input files in output container (default = TRUE)
# --switch-log
#   Print switch log to file (default = FALSE)
# --timestep-multiplier
#   Timestep multiplier for SSE and BSE (default = 1.000000)
# --use-mass-loss
#   Enable mass loss (default = TRUE)
# --version [ -v ]
#   Print COMPAS version string
# --wolf-rayet-multiplier
#   Multiplicitive constant for WR winds (default = 1.000000)
# --zeta-adiabatic-arbitrary
#   Value of mass-radius exponent zeta adiabatic (default = 10000.000000)
# --zeta-main-sequence
#   Value of mass-radius exponent zeta on the main sequence (default = 2.000000)
# --zeta-radiative-envelope-giant
#   Value of mass-radius exponent zeta for radiative envelope giants (default = 6.500000)

# %% [markdown]
# # 2. Reading HDF5 files
#
# ## Here we show the basic h5 file syntax for how to load and close the file, and extract/inspect the data.

# %% [markdown]
# ## Load the h5 file

# %%
# Set the appropriate path to the data file

pathToH5 = tutorialDir + 'COMPAS_Output/COMPAS_Output.h5' 
Data  = h5.File(pathToH5)

# %% [markdown]
# ## Inspect the data

# %%
list(Data.keys())
# Out:
# ['BSE_Common_Envelopes',
#  'BSE_Double_Compact_Objects',
#  'BSE_RLOF',
#  'BSE_Supernovae',
#  'BSE_System_Parameters',
#  'Run_Details']

# %% [markdown]
# The list of output here depends on your simulation. Here you may see 'BSE_System_Parameters', which collects all of the information of the systems at the beginning of the evolution, as well as other major events such as 'BSE_RLOF' for all mass transfer events, 'BSE_Common_Envelopes' for all unstable mass transfer events, 'BSE_Supernovae' if you have sufficiently massive stars to undergo a supernova event, and 'BSE_Double_Compact_Objects' if you happen to form any intact binaries composed of either neutron stars or black holes (though this is quite rare and may require a large simulation).
#
# Running Single Stellar Evolution (SSE) will produce generally different outputs to Binary Stellar Evolution (BSE), but both will create a Run_Details file, which captures all of the input settings.

# %% [markdown]
# ### To show all the parameters in a given file

# %%
# It is a pain to write the entire group each time so we define shorthands
SPs = Data['BSE_System_Parameters']
list(SPs.keys())
# Out:
# ['CE_Alpha',
#  'CH_on_MS(1)',
#  'CH_on_MS(2)',
#  'Eccentricity@ZAMS',
#  'Equilibrated_At_Birth',
#  'Error',
#  'LBV_Factor',
#  'Mass@ZAMS(1)',
#  'Mass@ZAMS(2)',
#  'Merger',
#  'Merger_At_Birth',
#  'Metallicity@ZAMS(1)',
#  'Metallicity@ZAMS(2)',
#  'Omega@ZAMS(1)',
#  'Omega@ZAMS(2)',
#  'SEED',
#  'SN_Kick_Magnitude_Random_Number(1)',
#  'SN_Kick_Magnitude_Random_Number(2)',
#  'SemiMajorAxis@ZAMS',
#  'Sigma_Kick_CCSN_BH',
#  'Sigma_Kick_CCSN_NS',
#  'Sigma_Kick_ECSN',
#  'Sigma_Kick_USSN',
#  'Stellar_Type(1)',
#  'Stellar_Type(2)',
#  'Stellar_Type@ZAMS(1)',
#  'Stellar_Type@ZAMS(2)',
#  'Unbound',
#  'WR_Factor']

# %% [markdown]
# ### To find the unit of a single parameter

# %%
print(SPs['Mass@ZAMS(1)'].attrs['units']) # attrs refers to attributes
# Out:
# b'Msol'

# %% [markdown]
# ### To access the values of a column

# %%
#Giving me the actual array
mZams1 = SPs['Mass@ZAMS(1)'][()]
print(mZams1.shape)                   # number of systems in this file
print(mZams1[:10])                    # the values of the first 10 entries
# Out:
# (1000,)
# [15.15094497  7.30378317  5.11526727  6.1482962  12.36056727  9.40913057
#  12.49265709 16.39926464  8.72331038 15.86012473]

# %% [markdown]
# ### To view all of the contents of a given HDF5 group, use the printCompasDetails function

# %%
printCompasDetails(SPs) # Note - the output of this is a pandas dataframe
# Out:
# SEED                               (units)  1636090177  1636090178  \
# CE_Alpha                                 -    1.000000    1.000000
# CH_on_MS(1)                          State    0.000000    0.000000
# CH_on_MS(2)                          State    0.000000    0.000000
# Eccentricity@ZAMS                        -    0.000000    0.000000
# Equilibrated_At_Birth                Event    0.000000    0.000000
# Error                                    -    0.000000    0.000000
# LBV_Factor                               -    1.500000    1.500000
# Mass@ZAMS(1)                          Msol   15.150945    7.303783
# Mass@ZAMS(2)                          Msol    4.360026    6.176230
# Merger                               Event    1.000000    0.000000
# Merger_At_Birth                      Event    0.000000    0.000000
# Metallicity@ZAMS(1)                      -    0.014200    0.014200
# Metallicity@ZAMS(2)                      -    0.014200    0.014200
# Omega@ZAMS(1)                           Hz    0.000000    0.000000
# Omega@ZAMS(2)                           Hz    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)       -    0.038219    0.034138
# SN_Kick_Magnitude_Random_Number(2)       -    0.969422    0.773873
# SemiMajorAxis@ZAMS                      AU    1.326351  361.863453
# Sigma_Kick_CCSN_BH                  kms^-1  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  kms^-1  265.000000  265.000000
# Sigma_Kick_ECSN                     kms^-1   30.000000   30.000000
# Sigma_Kick_USSN                     kms^-1   30.000000   30.000000
# Stellar_Type(1)                          -    7.000000   12.000000
# Stellar_Type(2)                          -    1.000000   11.000000
# Stellar_Type@ZAMS(1)                     -    1.000000    1.000000
# Stellar_Type@ZAMS(2)                     -    1.000000    1.000000
# Unbound                              State    0.000000    0.000000
# WR_Factor                                -    1.000000    1.000000
#
# SEED                                1636090179  1636090180  1636090181  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                          5.115267    6.148296   12.360567
# Mass@ZAMS(2)                          1.061175    5.398415    3.095323
# Merger                                0.000000    0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.240084    0.156188    0.609074
# SN_Kick_Magnitude_Random_Number(2)    0.592747    0.846536    0.339485
# SemiMajorAxis@ZAMS                    1.399115   18.816054  330.677207
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                      11.000000   11.000000   13.000000
# Stellar_Type(2)                      10.000000   11.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    0.000000    1.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636090182  1636090183  1636090184  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                          9.409131   12.492657   16.399265
# Mass@ZAMS(2)                          3.089870    4.059830   15.634044
# Merger                                0.000000    0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.806186    0.314751    0.096975
# SN_Kick_Magnitude_Random_Number(2)    0.832593    0.245217    0.028697
# SemiMajorAxis@ZAMS                    0.302815  588.524697   57.817667
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                      11.000000   13.000000   13.000000
# Stellar_Type(2)                      10.000000    1.000000    4.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    1.000000    1.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636090185  ...  1636091167  1636091168  \
# CE_Alpha                              1.000000  ...    1.000000    1.000000
# CH_on_MS(1)                           0.000000  ...    0.000000    0.000000
# CH_on_MS(2)                           0.000000  ...    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000  ...    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000  ...    0.000000    0.000000
# Error                                 0.000000  ...    0.000000    0.000000
# LBV_Factor                            1.500000  ...    1.500000    1.500000
# Mass@ZAMS(1)                          8.723310  ...    8.803164   10.762356
# Mass@ZAMS(2)                          1.082531  ...    3.733252    5.639837
# Merger                                1.000000  ...    0.000000    0.000000
# Merger_At_Birth                       0.000000  ...    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200  ...    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200  ...    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000  ...    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000  ...    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.449528  ...    0.091480    0.221552
# SN_Kick_Magnitude_Random_Number(2)    0.933196  ...    0.448100    0.773764
# SemiMajorAxis@ZAMS                    0.167502  ...  248.150928    2.721802
# Sigma_Kick_CCSN_BH                  265.000000  ...  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  ...  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000  ...   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000  ...   30.000000   30.000000
# Stellar_Type(1)                      10.000000  ...   13.000000   15.000000
# Stellar_Type(2)                       1.000000  ...    1.000000    7.000000
# Stellar_Type@ZAMS(1)                  1.000000  ...    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000  ...    1.000000    1.000000
# Unbound                               0.000000  ...    1.000000    0.000000
# WR_Factor                             1.000000  ...    1.000000    1.000000
#
# SEED                                1636091169  1636091170  1636091171  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                          5.513340    7.444313    8.203689
# Mass@ZAMS(2)                          1.654975    0.350391    1.367229
# Merger                                1.000000    0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.255263    0.728143    0.547435
# SN_Kick_Magnitude_Random_Number(2)    0.559361    0.605744    0.054735
# SemiMajorAxis@ZAMS                    0.030432  210.116416   28.361237
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       1.000000   12.000000   13.000000
# Stellar_Type(2)                       1.000000    0.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    0.000000    1.000000
# Unbound                               0.000000    0.000000    1.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636091172  1636091173  1636091174  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         21.979733   11.785701   12.654168
# Mass@ZAMS(2)                          0.610634    0.585199    1.536171
# Merger                                1.000000    0.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.591180    0.203628    0.466653
# SN_Kick_Magnitude_Random_Number(2)    0.575479    0.715417    0.197868
# SemiMajorAxis@ZAMS                    0.203405  188.822210    0.481434
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       7.000000   13.000000    7.000000
# Stellar_Type(2)                       0.000000    0.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  0.000000    0.000000    1.000000
# Unbound                               0.000000    1.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636091175  1636091176
# CE_Alpha                              1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000
# Error                                 0.000000    0.000000
# LBV_Factor                            1.500000    1.500000
# Mass@ZAMS(1)                          7.288199    9.392270
# Mass@ZAMS(2)                          7.062301    0.300414
# Merger                                0.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.717949    0.825319
# SN_Kick_Magnitude_Random_Number(2)    0.406343    0.222959
# SemiMajorAxis@ZAMS                    0.165029    0.111896
# Sigma_Kick_CCSN_BH                  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000
# Stellar_Type(1)                      11.000000   10.000000
# Stellar_Type(2)                      13.000000    0.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    0.000000
# Unbound                               1.000000    0.000000
# WR_Factor                             1.000000    1.000000
#
# [28 rows x 1001 columns]

# %% [markdown]
# ## Closing the Data
#
# Accessing a single h5file from multiple scripts is not always possible.
# With notebooks, sometimes closing the notebook is not enough to have it
# close the h5data. Therefore we recommend to close the h5file explicitly after
# the calculations are done

# %%
Data.close()

# %% [markdown]
# # 3. Rewriting HDF5 files
#
# The COMPAS simulations might be very large in data size while the actual data you need to reproduce your results could be small. Hence it might make sense to reduced the number of files and columns based on some criteria.
#
# ## Here we show how you can reduce your data. You need to decide:
#
# ### - Which data categories (or HDF5 groups) you want to include
# ### - Which seeds and parameters from each data category.

# %% [markdown]
# ## Load the Data

# %%
# Set the appropriate paths to the input and output data files
pathToDataInput = pathToH5 # use the output from the run above
pathToDataOutput = tutorialDir + '/COMPAS_Output/COMPAS_Output_reduced.h5' 

Data  = h5.File(pathToDataInput)
print("The main files I have at my disposal are:\n",list(Data.keys()))
# Out:
# The main files I have at my disposal are:
#  ['BSE_Common_Envelopes', 'BSE_Double_Compact_Objects', 'BSE_RLOF', 'BSE_Supernovae', 'BSE_System_Parameters', 'Run_Details']

# %% [markdown]
# ## Specify the data categories and parameters and columns
#
# We use dictionaries to specifically link all the entries.
#
# The columnsOfInterest dictionary maps the data categories you wish to include to their appropriate parameters of interest. The seedsOfInterest dictionary maps the data categories to a list of desired seeds. If you wish to exclude some of the systems, that can be accomplished by applying a mask onto the seeds array.

# %% [markdown]
# ### Hypothetical Example
#
# Suppose you are studying Double Neutron Star systems, and you want to know the initial parameters of both components. Suppose you are separately curious about the eccentricity of systems following a Supernova that leaves the binary intact, and you want to use the same COMPAS run to save on CPU*hours.
#
# To be safe, you should probably keep the entire BSE_System_Parameters file, which contains all of the initial system settings.
#
# To get information about only Double Neutron Stars, you will need to create a mask for them from the BSE_Double_Compact_Objects file.
#
# Information on post-SN eccentricity and whether or not the system disrupted is found in the BSE_Supernovae file.
#
# You will not need any other files. You will also want to grab the system 'SEED's column from any file, since that is the unique identifier of the binaries.

# %%
### For each data category, give a list of parameters you want to include
columnsOfInterest = {'BSE_System_Parameters':      ['All'],
                     'BSE_Double_Compact_Objects': ['All'],
                     'BSE_Supernovae':             ['SEED', 'Eccentricity']
                    }

# The seedsOfInterest are a little more involved

# %% [markdown]
# ## Select the desired seeds

# %%
### BSE_System_Parameters - keep all seeds
SPs = Data['BSE_System_Parameters']
seedsSP = SPs['SEED'][()]


### BSE_Double_Compact_Objects - keep only Double Neutron Stars
DCs = Data['BSE_Double_Compact_Objects']
seedsDC =  DCs['SEED'][()]
stellarType1   =  DCs['Stellar_Type(1)'][()]
stellarType2   =  DCs['Stellar_Type(2)'][()]

# Stellar type 13 corresponds to Neutron Stars
maskDNS        =  (stellarType1 == 13) & (stellarType2 == 13)
seedsDNS       =  seedsDC[maskDNS]


### BSE_Supernovae - keep only binaries which stay intact post-SN
SNe = Data['BSE_Supernovae']
seedsSN = SNe['SEED']
isUnbound    = SNe['Unbound'][()] == 1
isIntact     = ~isUnbound

seedsIntact  = seedsSN[isIntact]



### Create seedsOfInterest dictionary 
seedsOfInterest   = {'BSE_System_Parameters':      seedsSP,
                     'BSE_Double_Compact_Objects': seedsDNS,
                     'BSE_Supernovae':             seedsIntact
                    }


### Don't forget to close the original h5 data file
Data.close()

# %% [markdown]
# ## Call the function which creates the h5 file

# %%
rewrite_H5.reduceH5(pathToOld = pathToDataInput, pathToNew = pathToDataOutput,\
                     dictColumns=columnsOfInterest, dictSeeds=seedsOfInterest)

rewrite_H5.printAllColumnsInH5(pathToDataOutput)
# Out:
# Filename = BSE_Double_Compact_Objects
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Coalescence_Time                        b'Myr'                 0
# 	   Eccentricity@DCO                        b'-'                   0
# 	   Mass(1)                                 b'Msol'                0
# 	   Mass(2)                                 b'Msol'                0
# 	   Merges_Hubble_Time                      b'State'               0
# 	   --------------------------------------------------------------------
# 	   Recycled_NS(1)                          b'Event'               0
# 	   Recycled_NS(2)                          b'Event'               0
# 	   SEED                                    b'-'                   0
# 	   SemiMajorAxis@DCO                       b'AU'                  0
# 	   Stellar_Type(1)                         b'-'                   0
# 	   --------------------------------------------------------------------
# 	   Stellar_Type(2)                         b'-'                   0
# 	   Time                                    b'Myr'                 0
#
# Filename = BSE_Supernovae
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Eccentricity                            b'-'                   59
# 	   SEED                                    b'-'                   59
#
# Filename = BSE_System_Parameters
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   CE_Alpha                                b'-'                   1000
# 	   CH_on_MS(1)                             b'State'               1000
# 	   CH_on_MS(2)                             b'State'               1000
# 	   Eccentricity@ZAMS                       b'-'                   1000
# 	   Equilibrated_At_Birth                   b'Event'               1000
# 	   --------------------------------------------------------------------
# 	   Error                                   b'-'                   1000
# 	   LBV_Factor                              b'-'                   1000
# 	   Mass@ZAMS(1)                            b'Msol'                1000
# 	   Mass@ZAMS(2)                            b'Msol'                1000
# 	   Merger                                  b'Event'               1000
# 	   --------------------------------------------------------------------
# 	   Merger_At_Birth                         b'Event'               1000
# 	   Metallicity@ZAMS(1)                     b'-'                   1000
# 	   Metallicity@ZAMS(2)                     b'-'                   1000
# 	   Omega@ZAMS(1)                           b'Hz'                  1000
# 	   Omega@ZAMS(2)                           b'Hz'                  1000
# 	   --------------------------------------------------------------------
# 	   SEED                                    b'-'                   1000
# 	   SN_Kick_Magnitude_Random_Number(1)      b'-'                   1000
# 	   SN_Kick_Magnitude_Random_Number(2)      b'-'                   1000
# 	   SemiMajorAxis@ZAMS                      b'AU'                  1000
# 	   Sigma_Kick_CCSN_BH                      b'kms^-1'              1000
# 	   --------------------------------------------------------------------
# 	   Sigma_Kick_CCSN_NS                      b'kms^-1'              1000
# 	   Sigma_Kick_ECSN                         b'kms^-1'              1000
# 	   Sigma_Kick_USSN                         b'kms^-1'              1000
# 	   Stellar_Type(1)                         b'-'                   1000
# 	   Stellar_Type(2)                         b'-'                   1000
# 	   --------------------------------------------------------------------
# 	   Stellar_Type@ZAMS(1)                    b'-'                   1000
# 	   Stellar_Type@ZAMS(2)                    b'-'                   1000
# 	   Unbound                                 b'State'               1000
# 	   WR_Factor                               b'-'                   1000

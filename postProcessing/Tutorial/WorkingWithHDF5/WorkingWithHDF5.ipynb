# %% [markdown]
# # Introduction
#
# COMPAS simulations produce all output by default in the form of an [HDF5 file](https://www.hdfgroup.org/solutions/hdf5/), which is a compact and memory efficient, but non-human-readable data file format. In order to interact with these output files, we use the python module `h5py`.
#
# Within each file are a variety of HDF5 Groups, representing a specific common event in binary evolution, e.g Roche-Lobe Overflow or Supernovae. These are described throughout the post-processing jupyter notebooks.

# %% [markdown]
# ## Material
#
# ### [1. Producing HDF5 output:](#1.-Producing-HDF5-output)
# How to run default COMPAS and produce a simple output file.
#
#
# ### [2. Reading HDF5 files:](#2.-Reading-HDF5-files)
# The basics and syntax of loading an HDF5 file.
#
#
# ### [3. Rewriting HDF5 files:](#3.-Rewriting-HDF5-files)
# How to rewrite/reduce the HDF5 data.

# %%
import os, sys    # for handling paths
import h5py as h5  #for handling data format

# Import COMPAS root and python script directories
compasRootDir = os.environ['COMPAS_ROOT_DIR'] 
sys.path.append(compasRootDir + 'postProcessing/PythonScripts')

# Compas custom scripts used here
from printCompasDetails import printCompasDetails
import rewrite_H5

# %% [markdown]
# # 1. Producing HDF5 output
#
# ## Here we show an example of how to run a basic COMPAS simulation in order to produce output in an HDF5 format. To run COMPAS, you need to set the environment variable $COMPAS_ROOT_DIR to the top level COMPAS directory. Ensure that you have compiled COMPAS, and that there is a COMPAS executable. We will store the output in the Tutorial directory for easy access later on.
#
# ## For simplicity, we will run COMPAS on all default settings except for the number of binaries produced. Here, we will run 1k binaries, which is relatively small. Later, we will look at production of double compact objects (DCOs), but these objects are sufficiently rare that in order to study them, we will need to run a simulation of ~1M binaries, but this can take some time depending on your hardware resources.
#
# ### *Note:* It is required to have some COMPAS output to complete the rest of the post-processing notebooks, but if you already have an output file, you can skip this section.

# %%
# To run terminal commands in a jupyter notebook, prepend the command with an exclamation mark
# !COMPAS -n 1000 -o {outputDir}
# Out:
# COMPAS v02.24.02
# Compact Object Mergers: Population Astrophysics and Statistics
# by Team COMPAS (http://compas.science/index.html)
# A binary star simulator
#
# Start generating binaries at Fri Nov  5 16:14:58 2021
#
# 0: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 1: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 2: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 3: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 4: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 5: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 6: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 7: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 8: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 9: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 10: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 11: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 12: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 13: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap)
# 14: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 15: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 16: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 17: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 18: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 19: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 20: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 21: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 22: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 23: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 24: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 25: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 26: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 27: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 28: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 29: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 30: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 31: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 32: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 33: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 34: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 35: Allowed time exceeded: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 36: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 37: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 38: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 39: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 40: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 41: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 42: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 43: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 44: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 45: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 46: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 47: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 48: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 49: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 50: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 51: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 52: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 53: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 54: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 55: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 56: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 57: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 58: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 59: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 60: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 61: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 62: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 63: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 64: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 65: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 66: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 67: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 68: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 69: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 70: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 71: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 72: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 73: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 74: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 75: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 76: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap)
# 77: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 78: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 79: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 80: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 81: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 82: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 83: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 84: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 85: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 86: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 87: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 88: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 89: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 90: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 91: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 92: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 93: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 94: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 95: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 96: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 97: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 98: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 99: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 100: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 101: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 102: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 103: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 104: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 105: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 106: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 107: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 108: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 109: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 110: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 111: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 112: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 113: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 114: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 115: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 116: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 117: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 118: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 119: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 120: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 121: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 122: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 123: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 124: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 125: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 126: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 127: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 128: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 129: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 130: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 131: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 132: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 133: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 134: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 135: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 136: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 137: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 138: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 139: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 140: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 141: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 142: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 143: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 144: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 145: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 146: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 147: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 148: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 149: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 150: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 151: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 152: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 153: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 154: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 155: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 156: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 157: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 158: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 159: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 160: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 161: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 162: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 163: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 164: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 165: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 166: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 167: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 168: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 169: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 170: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 171: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 172: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 173: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 174: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 175: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 176: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 177: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 178: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 179: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 180: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 181: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 182: Double White Dwarf: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 183: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 184: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 185: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 186: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 187: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 188: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 189: Stars merged: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 190: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 191: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 192: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 193: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 194: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 195: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 196: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 197: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 198: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 199: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 200: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 201: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 202: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 203: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 204: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 205: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 206: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 207: Double White Dwarf: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 208: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 209: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 210: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 211: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 212: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 213: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 214: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 215: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 216: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 217: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 218: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 219: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 220: Stars merged: (Chemically_Homogeneous -> Main_Sequence_>_0.7) + (Chemically_Homogeneous -> Main_Sequence_>_0.7)
# 221: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 222: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 223: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 224: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 225: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 226: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 227: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 228: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 229: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 230: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 231: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 232: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 233: Stars merged: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 234: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 235: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 236: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 237: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 238: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 239: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 240: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 241: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 242: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 243: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 244: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 245: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 246: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 247: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 248: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 249: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 250: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 251: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 252: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 253: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 254: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 255: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 256: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 257: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 258: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 259: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 260: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 261: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 262: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 263: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 264: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 265: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 266: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 267: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 268: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 269: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 270: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 271: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 272: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 273: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Black_Hole)
# 274: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 275: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 276: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 277: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 278: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 279: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 280: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 281: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 282: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 283: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 284: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 285: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 286: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 287: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 288: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 289: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 290: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 291: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 292: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 293: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 294: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 295: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 296: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 297: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 298: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 299: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 300: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 301: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 302: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 303: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 304: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 305: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 306: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 307: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 308: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 309: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 310: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 311: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 312: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 313: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 314: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 315: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 316: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 317: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 318: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 319: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 320: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 321: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 322: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 323: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 324: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 325: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 326: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 327: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 328: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 329: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 330: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 331: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 332: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 333: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 334: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 335: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 336: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 337: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 338: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 339: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 340: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 341: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 342: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 343: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 344: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 345: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 346: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 347: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 348: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 349: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 350: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 351: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 352: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 353: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 354: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 355: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 356: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap)
# 357: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 358: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 359: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 360: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 361: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 362: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 363: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 364: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 365: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 366: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 367: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 368: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 369: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 370: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 371: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 372: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 373: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 374: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 375: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 376: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 377: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 378: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 379: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 380: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 381: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 382: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 383: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 384: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 385: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 386: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 387: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 388: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 389: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 390: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 391: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 392: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 393: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 394: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 395: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 396: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 397: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 398: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 399: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 400: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 401: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 402: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 403: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 404: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 405: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 406: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 407: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 408: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 409: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 410: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 411: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 412: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap)
# 413: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 414: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 415: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 416: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 417: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 418: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# ...
# 863: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 864: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 865: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 866: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 867: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 868: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 869: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 870: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 871: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 872: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 873: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 874: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 875: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 876: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 877: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 878: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 879: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 880: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 881: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 882: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 883: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 884: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 885: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 886: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 887: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 888: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 889: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 890: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 891: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 892: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 893: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 894: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 895: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 896: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 897: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 898: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 899: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 900: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 901: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 902: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 903: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 904: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 905: Allowed time exceeded: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 906: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 907: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 908: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 909: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 910: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 911: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 912: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 913: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 914: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 915: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 916: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 917: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 918: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 919: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 920: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 921: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 922: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 923: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 924: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 925: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 926: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 927: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 928: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 929: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 930: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 931: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 932: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 933: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 934: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 935: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 936: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 937: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 938: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 939: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 940: Stars merged: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 941: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 942: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 943: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 944: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 945: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 946: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 947: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 948: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 949: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 950: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 951: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 952: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 953: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 954: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 955: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 956: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 957: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 958: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 959: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 960: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 961: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 962: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 963: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 964: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 965: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 966: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 967: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 968: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 969: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 970: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 971: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 972: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 973: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 974: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 975: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 976: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 977: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 978: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 979: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 980: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 981: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 982: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 983: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 984: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 985: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 986: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 987: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 988: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 989: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 990: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 991: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 992: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 993: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 994: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 995: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 996: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 997: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 998: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 999: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
#
# Generated 1000 of 1000 binaries requested
#
# Simulation completed
#
# End generating binaries at Fri Nov  5 16:15:15 2021
#
# Clock time = 17.3465 CPU seconds
# Wall time  = 0000:00:17 (hhhh:mm:ss)

# %% [markdown]
# ### *Note:* This will produce output in the COMPAS_Output directory only the first time it is run. If you run this multiple times, new directories will be created as COMPAS_Output_X. Ensure that you are using the data in the desired directory.

# %% [markdown]
# ## Non-default settings can be seen by running the following in the command line

# %%
# !COMPAS --help
# Out:
# COMPAS v02.24.02
# Compact Object Mergers: Population Astrophysics and Statistics
# by Team COMPAS (http://compas.science/index.html)
# A binary star simulator
#
# Options:
# --PISN-lower-limit
#   Minimum core mass for PISN, in Msol (default = 60.000000)
# --PISN-upper-limit
#   Maximum core mass for PISN, in Msol (default = 135.000000)
# --PPI-lower-limit
#   Minimum core mass for PPI, in Msol (default = 35.000000)
# --PPI-upper-limit
#   Maximum core mass for PPI, in Msol (default = 60.000000)
# --add-options-to-sysparms
#   Add program options columns to BSE/SSE SysParms file (options: [ALWAYS, GRID, NEVER], default = GRID)
# --allow-rlof-at-birth
#   Allow binaries that have one or both stars in RLOF at birth to evolve (default = TRUE)
# --allow-touching-at-birth
#   Allow binaries that are touching at birth to evolve (default = FALSE)
# --angular-momentum-conservation-during-circularisation
#   Conserve angular momentum when binary is circularised when entering a Mass Transfer episode (default = FALSE)
# --black-hole-kicks
#   Black hole kicks relative to NS kicks (options: [FULL, REDUCED, ZERO, FALLBACK], default = FALLBACK)
# --case-BB-stability-prescription
#   Case BB/BC mass transfer stability prescription (options: [ALWAYS_STABLE, ALWAYS_STABLE_ONTO_NSBH, TREAT_AS_OTHER_MT, ALWAYS_UNSTABLE], default = ALWAYS_STABLE)
# --check-photon-tiring-limit
#   Check the photon tiring limit hasn't been exceeded by wind mass loss (default = FALSE)
# --chemically-homogeneous-evolution
#   Chemically Homogeneous Evolution (options: [NONE, OPTIMISTIC, PESSIMISTIC], default = PESSIMISTIC)
# --circularise-binary-during-mass-transfer
#   Circularise binary when it enters a Mass Transfer episode (default = TRUE)
# --common-envelope-allow-main-sequence-survive
#   Allow main sequence stars to survive common envelope evolution (default = TRUE)
# --common-envelope-alpha
#   Common Envelope efficiency alpha (default = 1.000000)
# --common-envelope-alpha-thermal
#   Defined such that lambda = alpha_th * lambda_b + (1.0 - alpha_th) * lambda_g (default = 1.000000)
# --common-envelope-lambda
#   Common Envelope lambda (default = 0.100000)
# --common-envelope-lambda-multiplier
#   Multiply lambda by some constant (default = 1.000000)
# --common-envelope-lambda-prescription
#   CE lambda prescription (options: [LAMBDA_FIXED, LAMBDA_LOVERIDGE, LAMBDA_NANJING, LAMBDA_KRUCKOW, LAMBDA_DEWI], default = LAMBDA_NANJING)
# --common-envelope-mass-accretion-constant
#   Value of mass accreted by NS/BH, in Msol, during common envelope evolution, assuming all NS/BH accrete same amount of mass (common-envelope-mass-accretion-prescription CONSTANT). Ignored otherwise (default = 0.000000)
# --common-envelope-mass-accretion-max
#   Maximum amount of mass accreted by NS/BHs, in Msol, during common envelope evolution in Msol (default = 0.100000)
# --common-envelope-mass-accretion-min
#   Minimum amount of mass accreted by NS/BHs, in Msol, during common envelope evolution in Msol (default = 0.040000)
# --common-envelope-mass-accretion-prescription
#   Assumption about whether NS/BHs can accrete mass during common envelope evolution (options: [ZERO, CONSTANT, UNIFORM, MACLEOD], default = ZERO)
# --common-envelope-recombination-energy-density
#   Recombination energy density, in erg/g (default = 15000000000000.000000)
# --common-envelope-slope-kruckow
#   Common Envelope slope for Kruckow lambda (default = -0.833333)
# --cool-wind-mass-loss-multiplier
#   Multiplicative constant for wind mass loss of cool stars (default = 1.000000)
# --debug-classes
#   Debug classes enabled (default = )
# --debug-level
#   Determines which print statements are displayed for debugging (default = 0)
# --debug-to-file
#   Write debug statements to file (default = FALSE)
# --detailed-output
#   Print detailed output to file (default = FALSE)
# --eccentricity [ -e ]
#   Eccentricity, e (default = 0.000000)
# --eccentricity-distribution
#   Initial eccentricity distribution (options: [ZERO, FLAT, THERMAL, GELLER+2013, DUQUENNOYMAYOR1991, SANA2012], default = ZERO)
# --eccentricity-max
#   Maximum eccentricity to generate (default = 1.000000)
# --eccentricity-min
#   Minimum eccentricity to generate (default = 0.000000)
# --eddington-accretion-factor
#   Multiplication factor for eddington accretion for NS & BH, i.e. >1 is super-eddington and 0. is no accretion (default = 1.000000)
# --enable-warnings
#   Display warning messages to stdout (default = FALSE)
# --envelope-state-prescription
#   Prescription for whether the envelope is radiative or convective (options: [LEGACY, HURLEY, FIXED_TEMPERATURE], default = LEGACY)
# --errors-to-file
#   Write error messages to file (default = FALSE)
# --evolve-pulsars
#   Evolve pulsars (default = FALSE)
# --evolve-unbound-systems
#   Continue evolving stars even if the binary is disrupted (default = FALSE)
# --fix-dimensionless-kick-magnitude
#   Fix dimensionless kick magnitude uk to this value (default = -1.000000, -ve values false, +ve values true)
# --fryer-supernova-engine
#   If using Fryer et al 2012 fallback prescription. (options: [DELAYED, RAPID], default = DELAYED)
# --grid
#   Grid filename (default = )
# --grid-lines-to-process
#   Specifies how many grid lines should be processed (from the start line - see grid-start-line) (default = Process to EOF)
# --grid-start-line
#   Specifies which line of the grid file is processed first (0-based) (default = 0)
# --hdf5-buffer-size
#   HDF5 file dataset IO buffer size (number of chunks, default = 1)
# --hdf5-chunk-size
#   HDF5 file dataset chunk size (number of dataset entries, default = 100000)
# --help [ -h ]
#   Print this help message
# --initial-mass
#   Initial mass (in Msol) for the star (SSE) (default = 5.000000)
# --initial-mass-1
#   Initial mass (in Msol) for the primary star (BSE) (default = 5.000000)
# --initial-mass-2
#   Initial mass (in Msol) for the secondary star (BSE) (default = 5.000000)
# --initial-mass-function [ -i ]
#   Initial mass function (options: [SALPETER, POWERLAW, UNIFORM, KROUPA], default = KROUPA)
# --initial-mass-max
#   Maximum mass (in Msol) to generate using given IMF (default = 150.000000)
# --initial-mass-min
#   Minimum mass (in Msol) to generate using given IMF (default = 5.000000)
# --initial-mass-power
#   Single power law power to generate primary mass using POWERLAW IMF (default = 0.000000)
# --kick-direction
#   Natal kick direction distribution (options: [ISOTROPIC, INPLANE, PERPENDICULAR, POWERLAW, WEDGE, POLES], default = ISOTROPIC)
# --kick-direction-power
#   Power for power law kick direction distribution (default = 0.000000 = isotropic, +ve = polar, -ve = in plane)
# --kick-magnitude
#   The magnitude of the kick velocity, in km/s, that the star receives during the a supernova (default = 0.000000)
# --kick-magnitude-1
#   The magnitude of the kick velocity, in km/s, that the primary star receives during the a supernova (default = 0.000000)
# --kick-magnitude-2
#   The magnitude of the kick velocity, in km/s, that the secondary star receives during the a supernova (default = 0.000000)
# --kick-magnitude-distribution
#   Natal kick magnitude distribution (options: [ZERO, FIXED, FLAT, MAXWELLIAN, BRAYELDRIDGE, MULLER2016, MULLER2016MAXWELLIAN, MULLERMANDEL], default = MAXWELLIAN)
# --kick-magnitude-max
#   Maximum drawn kick magnitude in km/s. Ignored if < 0. Must be > 0 if using kick-magnitude-distribution=FLAT (default = -1.000000)
# --kick-magnitude-random
#   Number used to choose the kick velocity magnitude for the star during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-random-1
#   Number used to choose the kick velocity magnitude for the primary star during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-random-2
#   Number used to choose the kick velocity magnitude for the secondary during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-sigma-CCSN-BH
#   Sigma for chosen kick magnitude distribution, in km/s, for black holes (default = 265.000000)
# --kick-magnitude-sigma-CCSN-NS
#   Sigma for chosen kick magnitude distribution, in km/s, for neutron stars (default = 265.000000)
# --kick-magnitude-sigma-ECSN
#   Sigma for chosen kick magnitude distribution, in km/s, for ECSN (default = 30.000000)
# --kick-magnitude-sigma-USSN
#   Sigma for chosen kick magnitude distribution, in km/s, for USSN (default = 30.000000)
# --kick-mean-anomaly-1
#   Mean anomaly, in rad, for the primary star at instantaneous time of the supernova (default = uniform random number [0.0, 2pi))
# --kick-mean-anomaly-2
#   Mean anomaly, in rad, for the secondary star at instantaneous time of the supernova (default = uniform random number [0.0, 2pi))
# --kick-phi-1
#   Planar angle, in rad, of the supernova vector, for the primary star (default = drawn from kick direction distribution)
# --kick-phi-2
#   Planar angle, in rad, of the supernova vector, for the secondary star (default = drawn from kick direction distribution)
# --kick-scaling-factor
#   Arbitrary factor used to scale kicks (default = 1.000000)
# --kick-theta-1
#   Polar angle, in rad, of the supernova vector, for the primary star (default = drawn from kick direction distribution)
# --kick-theta-2
#   Polar angle, in rad, of the supernova vector, for the secondary star (default = drawn from kick direction distribution)
# --log-classes
#   Logging classes enabled (default = )
# --log-level
#   Determines which print statements are included in the logfile (default = 0)
# --logfile-common-envelopes
#   Filename for BSE Common Envelopes logfile (default = BSE_Common_Envelopes)
# --logfile-definitions
#   Filename for logfile record definitions (default = )
# --logfile-detailed-output
#   Filename for BSE Detailed Output logfile (default = BSE_Detailed_Output)
# --logfile-double-compact-objects
#   Filename for Double Compact Objects logfile (default = BSE_Double_Compact_Objects)
# --logfile-name-prefix
#   Prefix for logfile names (default = )
# --logfile-pulsar-evolution
#   Filename for Pulsar Evolution logfile (default = BSE_Pulsar_Evolution)
# --logfile-rlof-parameters
#   Filename for BSE RLOF Parameters logfile ( default = BSE_RLOF)
# --logfile-supernovae
#   Filename for Supernovae logfile (default = BSE_Supernovae)
# --logfile-switch-log
#   Filename for Switch Log logfile (default = BSE_Switch_Log)
# --logfile-system-parameters
#   Filename for System Parameters logfile (default = BSE_System_Parameters)
# --logfile-type
#   File type for logfiles (options: [HDF5, CSV, TSV, TXT], default = HDF5)
# --luminous-blue-variable-multiplier
#   Multiplicitive constant for LBV mass loss (default = 1.500000, use 10 for Mennekens & Vanbeveren 2014)
# --luminous-blue-variable-prescription
#   LBV Mass loss prescription (options: [NONE, HURLEY_ADD, HURLEY, BELCZYNSKI], default = HURLEY_ADD)
# --mass-loss-prescription
#   Mass loss prescription (options: [NONE, HURLEY, VINK], default = VINK)
# --mass-ratio [ -q ]
#   Mass ratio m2/m1 used to determine secondary mass if not specified (default = 1.000000)
# --mass-ratio-distribution
#   Initial mass ratio distribution for q=m2/m1 (options: [FLAT, DUQUENNOYMAYOR1991, SANA2012], default = FLAT)
# --mass-ratio-max
#   Maximum mass ratio m2/m1 to generate (default = 1.000000)
# --mass-ratio-min
#   Minimum mass ratio m2/m1 to generate (default = 0.010000)
# --mass-transfer
#   Enable mass transfer (default = TRUE)
# --mass-transfer-accretion-efficiency-prescription
#   Mass Transfer Accretion Efficiency prescription (options: [THERMAL, FIXED], default = THERMAL)
# --mass-transfer-angular-momentum-loss-prescription
#   Mass Transfer Angular Momentum Loss prescription (options: [JEANS, ISOTROPIC, CIRCUMBINARY, ARBITRARY], default = ISOTROPIC)
# --mass-transfer-fa
#   Mass Transfer fraction accreted in FIXED prescription (default = 0.500000, fully conservative)
# --mass-transfer-jloss
#   Fraction of specific angular momentum which non-accreted matter removes from the system (default = 1.000000)
# --mass-transfer-rejuvenation-prescription
#   Mass Transfer Rejuvenation prescription (options: [NONE, STARTRACK], default = STARTRACK)
# --mass-transfer-thermal-limit-C
#   Mass Transfer Thermal rate factor of the accretor (default = 10.000000)
# --mass-transfer-thermal-limit-accretor
#   Mass Transfer Thermal Accretion limit (options: [CFACTOR, ROCHELOBE], default = CFACTOR)
# --maximum-evolution-time
#   Maximum time to evolve binaries, in Myr (default = 13700.000000)
# --maximum-mass-donor-nandez-ivanova
#   Maximum donor mass, in Msol, allowed for the revised common envelope formalism in Msol (default = 2.000000)
# --maximum-neutron-star-mass
#   Maximum mass of a neutron star, in Msol (default = 2.500000)
# --maximum-number-timestep-iterations
#   Maximum number of timesteps to evolve binary before giving up (default = 99999)
# --mcbur1
#   Minimum core mass at BAGB, in Msol, to avoid fully degenerate CO core  (default = 1.600000)
# --metallicity [ -z ]
#   Metallicity to use (default 0.014200)
# --metallicity-distribution
#   Metallicity distribution (options: [ZSOLAR, LOGUNIFORM], default = ZSOLAR)
# --metallicity-max
#   Maximum metallicity to generate (default = 0.030000)
# --metallicity-min
#   Minimum metallicity to generate (default = 0.000100)
# --minimum-secondary-mass
#   Minimum mass of secondary to generate, in Msol (default = 0.100000)
# --mode
#   Evolution mode (options: [SSE, BSE], default = BSE)
# --muller-mandel-kick-multiplier-BH
#   Scaling prefactor for BH kicks when using the 'MULLERMANDEL' kick magnitude distribution (default = 200.000000)
# --muller-mandel-kick-multiplier-NS
#   Scaling prefactor for NS kicks when using the 'MULLERMANDEL' kick magnitude distribution (default = 400.000000)
# --neutrino-mass-loss-BH-formation
#   Assumption about neutrino mass loss during BH formation (options: [FIXED_FRACTION, FIXED_MASS], default = FIXED_MASS)
# --neutrino-mass-loss-BH-formation-value
#   Amount of BH mass lost due to neutrinos (either fraction or fixed value, depending on --neutrino-mass-loss-BH-formation) (default = 0.100000)
# --neutron-star-equation-of-state
#   Neutron star equation of state to use (options: [SSE, ARP3], default = SSE)
# --number-of-systems [ -n ]
#   Specify the number of systems to simulate (SSE) (default = 10)
# --orbital-period
#   Initial orbital period, in days (default = 0.100000)
# --orbital-period-distribution
#   Initial orbital period distribution (options: [FLATINLOG], default = FLATINLOG)
# --orbital-period-max
#   Maximum period, in days, to generate (default = 1000.000000)
# --orbital-period-min
#   Minimum period, in days, to generate (default = 1.100000)
# --output-container [ -c ]
#   Container (directory) name for output files (default = COMPAS_Output)
# --output-path [ -o ]
#   Directory for output (default = .)
# --overall-wind-mass-loss-multiplier
#   Multiplicitive constant for overall wind mass loss (default = 1.000000)
# --pair-instability-supernovae
#   Enable pair instability supernovae (PISN) (default = TRUE)
# --population-data-printing
#   Print details of population (default = FALSE)
# --print-bool-as-string
#   Print boolean properties as 'TRUE' or 'FALSE' (default = FALSE)
# --pulsar-birth-magnetic-field-distribution
#   Pulsar Birth Magnetic Field distribution (options: [ZERO, FIXED, FLATINLOG, UNIFORM, LOGNORMAL], default = ZERO)
# --pulsar-birth-magnetic-field-distribution-max
#   Maximum pulsar birth magnetic field, in log10(Gauss) (default = 13.000000)
# --pulsar-birth-magnetic-field-distribution-min
#   Minimum pulsar birth magnetic field, in log10(Gauss) (default = 11.000000)
# --pulsar-birth-spin-period-distribution
#   Pulsar Birth Spin Period distribution (options: [ZERO, FIXED, UNIFORM, NORMAL], default = ZERO)
# --pulsar-birth-spin-period-distribution-max
#   Maximum pulsar birth spin period, in ms (default = 100.000000)
# --pulsar-birth-spin-period-distribution-min
#   Minimum pulsar birth spin period, in ms (default = 10.000000)
# --pulsar-magnetic-field-decay-massscale
#   Mass scale on which magnetic field decays during accretion, in Msol (default = 0.025000)
# --pulsar-magnetic-field-decay-timescale
#   Timescale on which magnetic field decays, in Myrs (default = 1000.000000)
# --pulsar-minimum-magnetic-field
#   Minimum pulsar magnetic field, in log10(Gauss) (default = 8.000000)
# --pulsational-pair-instability
#   Enable mass loss due to pulsational-pair-instability (PPI) (default = TRUE)
# --pulsational-pair-instability-prescription
#   Pulsational Pair Instability prescription (options: [COMPAS, STARTRACK, MARCHANT, FARMER], default = MARCHANT)
# --quiet
#   Suppress printing (default = FALSE)
# --random-seed
#   Random seed to use (default = 0)
# --remnant-mass-prescription
#   Choose remnant mass prescription (options: [HURLEY2000, BELCZYNSKI2002, FRYER2012, MULLER2016, MULLERMANDEL, SCHNEIDER2020, SCHNEIDER2020ALT], default = FRYER2012)
# --revised-energy-formalism-nandez-ivanova
#   Enable revised energy formalism (default = FALSE)
# --rlof-printing
#   Enable output parameters before/after RLOF (default = TRUE)
# --rotational-frequency
#   Initial rotational frequency for the star for SSE (Hz) (default = 0.000000)
# --rotational-frequency-1
#   Initial rotational frequency for the primary star for BSE (Hz) (default = 0.000000)
# --rotational-frequency-2
#   Initial rotational frequency for the secondary star for BSE (Hz) (default = 0.000000)
# --rotational-velocity-distribution
#   Initial rotational velocity distribution (options: [ZERO, HURLEY, VLTFLAMES], default = ZERO)
# --semi-major-axis [ -a ]
#   Initial semi-major axis, in AU (default = 0.100000)
# --semi-major-axis-distribution
#   Initial semi-major axis distribution (options: [FLATINLOG, CUSTOM, DUQUENNOYMAYOR1991, SANA2012], default = FLATINLOG)
# --semi-major-axis-max
#   Maximum semi-major axis, in AU, to generate (default = 1000.000000)
# --semi-major-axis-min
#   Minimum semi-major axis, in AU, to generate (default = 0.010000)
# --stellar-zeta-prescription
#   Prescription for stellar zeta (default = SOBERMAN)
# --store-input-files
#   Store input files in output container (default = TRUE)
# --switch-log
#   Print switch log to file (default = FALSE)
# --timestep-multiplier
#   Timestep multiplier for SSE and BSE (default = 1.000000)
# --use-mass-loss
#   Enable mass loss (default = TRUE)
# --version [ -v ]
#   Print COMPAS version string
# --wolf-rayet-multiplier
#   Multiplicitive constant for WR winds (default = 1.000000)
# --zeta-adiabatic-arbitrary
#   Value of mass-radius exponent zeta adiabatic (default = 10000.000000)
# --zeta-main-sequence
#   Value of mass-radius exponent zeta on the main sequence (default = 2.000000)
# --zeta-radiative-envelope-giant
#   Value of mass-radius exponent zeta for radiative envelope giants (default = 6.500000)

# %% [markdown]
# # 2. Reading HDF5 files
#
# ## Here we show the basic h5 file syntax for how to load and close the file, and extract/inspect the data.
#
# ### For this and the following sections, you will need to have the python package h5py installed.
#
# ### Running `pip install h5py` on the command line is one way to do this.

# %% [markdown]
# ## Load the h5 file

# %%
# Set the appropriate path to the data file

outputDir = compasRootDir + '/postProcessing/Tutorial/'
pathToH5 = outputDir + 'COMPAS_Output/COMPAS_Output.h5' 
Data  = h5.File(pathToH5)

# %% [markdown]
# ## Inspect the data

# %%
list(Data.keys())
# Out:
# ['BSE_Common_Envelopes',
#  'BSE_Double_Compact_Objects',
#  'BSE_RLOF',
#  'BSE_Supernovae',
#  'BSE_System_Parameters',
#  'Run_Details']

# %% [markdown]
# The list of output here depends on your simulation. Here you may see 'BSE_System_Parameters', which collects all of the information of the systems at the beginning of the evolution, as well as other major events such as 'BSE_RLOF' for all mass transfer events, 'BSE_Common_Envelopes' for all unstable mass transfer events, 'BSE_Supernovae' if you have sufficiently massive stars to undergo a supernova event, and 'BSE_Double_Compact_Objects' if you happen to form any intact binaries composed of either neutron stars or black holes (though this is quite rare and may require a large simulation).
#
# Running Single Stellar Evolution (SSE) will produce generally different outputs to Binary Stellar Evolution (BSE), but both will create a Run_Details file, which captures all of the input settings.

# %% [markdown]
# ### To show all the parameters in a given file

# %%
# It is a pain to write the entire group each time so we define shorthands
SPs = Data['BSE_System_Parameters']
list(SPs.keys())
# Out:
# ['CE_Alpha',
#  'CH_on_MS(1)',
#  'CH_on_MS(2)',
#  'Eccentricity@ZAMS',
#  'Equilibrated_At_Birth',
#  'Error',
#  'LBV_Factor',
#  'Mass@ZAMS(1)',
#  'Mass@ZAMS(2)',
#  'Merger',
#  'Merger_At_Birth',
#  'Metallicity@ZAMS(1)',
#  'Metallicity@ZAMS(2)',
#  'Omega@ZAMS(1)',
#  'Omega@ZAMS(2)',
#  'SEED',
#  'SN_Kick_Magnitude_Random_Number(1)',
#  'SN_Kick_Magnitude_Random_Number(2)',
#  'SemiMajorAxis@ZAMS',
#  'Sigma_Kick_CCSN_BH',
#  'Sigma_Kick_CCSN_NS',
#  'Sigma_Kick_ECSN',
#  'Sigma_Kick_USSN',
#  'Stellar_Type(1)',
#  'Stellar_Type(2)',
#  'Stellar_Type@ZAMS(1)',
#  'Stellar_Type@ZAMS(2)',
#  'Unbound',
#  'WR_Factor']

# %% [markdown]
# ### To find the unit of a single parameter

# %%
print(SPs['Mass@ZAMS(1)'].attrs['units']) # attrs refers to attributes
# Out:
# b'Msol'

# %% [markdown]
# ### To access the values of a column

# %%
#Giving me the actual array
mZams1 = SPs['Mass@ZAMS(1)'][()]
print(mZams1.shape)                   # number of systems in this file
print(mZams1[:10])                    # the values of the first 10 entries
# Out:
# (1000,)
# [ 5.60258003  6.67566692  5.34211519 19.10713389  9.22907701 10.96658811
#   5.42614827 10.23281107  5.48352169 12.6884035 ]

# %% [markdown]
# ### To restrict the data, you can apply a mask

# %%
SPs.keys()
# Out:
# <KeysViewHDF5 ['CE_Alpha', 'CH_on_MS(1)', 'CH_on_MS(2)', 'Eccentricity@ZAMS', 'Equilibrated_At_Birth', 'Error', 'LBV_Factor', 'Mass@ZAMS(1)', 'Mass@ZAMS(2)', 'Merger', 'Merger_At_Birth', 'Metallicity@ZAMS(1)', 'Metallicity@ZAMS(2)', 'Omega@ZAMS(1)', 'Omega@ZAMS(2)', 'SEED', 'SN_Kick_Magnitude_Random_Number(1)', 'SN_Kick_Magnitude_Random_Number(2)', 'SemiMajorAxis@ZAMS', 'Sigma_Kick_CCSN_BH', 'Sigma_Kick_CCSN_NS', 'Sigma_Kick_ECSN', 'Sigma_Kick_USSN', 'Stellar_Type(1)', 'Stellar_Type(2)', 'Stellar_Type@ZAMS(1)', 'Stellar_Type@ZAMS(2)', 'Unbound', 'WR_Factor']>

# %%
seedsSP = SPs['SEED'][()]
isMerger = SPs['Merger'][()] == 1
seedsOfMergers = seedsSP[isMerger]
print(len(seedsOfMergers)) # number of systems which end as mergers
# Out:
# 278

# %% [markdown]
# ### To view all of the contents of a given HDF5 group, use the printCompasDetails function

# %%
printCompasDetails(SPs) # Note - the output of this is a pandas dataframe
# Out:
# SEED                               (units)  1636013061  1636013062  \
# CE_Alpha                                 -    1.000000    1.000000
# CH_on_MS(1)                          State    0.000000    0.000000
# CH_on_MS(2)                          State    0.000000    0.000000
# Eccentricity@ZAMS                        -    0.000000    0.000000
# Equilibrated_At_Birth                Event    0.000000    0.000000
# Error                                    -    0.000000    0.000000
# LBV_Factor                               -    1.500000    1.500000
# Mass@ZAMS(1)                          Msol    5.602580    6.675667
# Mass@ZAMS(2)                          Msol    1.960830    0.433711
# Merger                               Event    1.000000    0.000000
# Merger_At_Birth                      Event    0.000000    0.000000
# Metallicity@ZAMS(1)                      -    0.014200    0.014200
# Metallicity@ZAMS(2)                      -    0.014200    0.014200
# Omega@ZAMS(1)                           Hz    0.000000    0.000000
# Omega@ZAMS(2)                           Hz    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)       -    0.513407    0.552386
# SN_Kick_Magnitude_Random_Number(2)       -    0.105358    0.007325
# SemiMajorAxis@ZAMS                      AU    0.027316    8.197483
# Sigma_Kick_CCSN_BH                  kms^-1  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  kms^-1  265.000000  265.000000
# Sigma_Kick_ECSN                     kms^-1   30.000000   30.000000
# Sigma_Kick_USSN                     kms^-1   30.000000   30.000000
# Stellar_Type(1)                          -    1.000000   12.000000
# Stellar_Type(2)                          -    1.000000    0.000000
# Stellar_Type@ZAMS(1)                     -    1.000000    1.000000
# Stellar_Type@ZAMS(2)                     -    1.000000    0.000000
# Unbound                              State    0.000000    0.000000
# WR_Factor                                -    1.000000    1.000000
#
# SEED                                1636013063  1636013064  1636013065  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                          5.342115   19.107134    9.229077
# Mass@ZAMS(2)                          4.056778   14.425355    0.997601
# Merger                                0.000000    1.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.031069    0.026566    0.267764
# SN_Kick_Magnitude_Random_Number(2)    0.356825    0.669016    0.807552
# SemiMajorAxis@ZAMS                   23.566130    0.206363   23.688253
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                      11.000000   13.000000   13.000000
# Stellar_Type(2)                      11.000000    7.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    0.000000    1.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636013066  1636013067  1636013068  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         10.966588    5.426148   10.232811
# Mass@ZAMS(2)                          5.196713    0.370113    4.988529
# Merger                                0.000000    0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.413978    0.635264    0.501486
# SN_Kick_Magnitude_Random_Number(2)    0.652217    0.474390    0.016928
# SemiMajorAxis@ZAMS                    0.301179    0.793393    0.313833
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                      13.000000   10.000000   11.000000
# Stellar_Type(2)                       1.000000    0.000000   11.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    0.000000    1.000000
# Unbound                               1.000000    0.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636013069  ...  1636014051  1636014052  \
# CE_Alpha                              1.000000  ...    1.000000    1.000000
# CH_on_MS(1)                           0.000000  ...    0.000000    0.000000
# CH_on_MS(2)                           0.000000  ...    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000  ...    0.000000    0.000000
# Equilibrated_At_Birth                 1.000000  ...    0.000000    0.000000
# Error                                 0.000000  ...    0.000000    0.000000
# LBV_Factor                            1.500000  ...    1.500000    1.500000
# Mass@ZAMS(1)                          5.483522  ...    6.911606    5.003489
# Mass@ZAMS(2)                          5.483522  ...    3.309290    4.322393
# Merger                                1.000000  ...    0.000000    0.000000
# Merger_At_Birth                       0.000000  ...    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200  ...    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200  ...    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000  ...    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000  ...    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.149545  ...    0.770952    0.953984
# SN_Kick_Magnitude_Random_Number(2)    0.437915  ...    0.647146    0.301934
# SemiMajorAxis@ZAMS                    0.028162  ...    0.783439    0.229700
# Sigma_Kick_CCSN_BH                  265.000000  ...  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  ...  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000  ...   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000  ...   30.000000   30.000000
# Stellar_Type(1)                       1.000000  ...   11.000000   11.000000
# Stellar_Type(2)                       1.000000  ...   11.000000   10.000000
# Stellar_Type@ZAMS(1)                  1.000000  ...    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000  ...    1.000000    1.000000
# Unbound                               0.000000  ...    0.000000    0.000000
# WR_Factor                             1.000000  ...    1.000000    1.000000
#
# SEED                                1636014053  1636014054  1636014055  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                          9.368128    9.050024   16.090188
# Mass@ZAMS(2)                          1.899884    2.779627    7.370224
# Merger                                1.000000    0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.292735    0.477672    0.286421
# SN_Kick_Magnitude_Random_Number(2)    0.443468    0.874978    0.527925
# SemiMajorAxis@ZAMS                    0.917777    0.108016    0.238171
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       7.000000   15.000000   13.000000
# Stellar_Type(2)                       1.000000    7.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    0.000000    1.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636014056  1636014057  1636014058  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         16.565732   17.030199    5.142841
# Mass@ZAMS(2)                          4.869101   10.509816    3.293935
# Merger                                1.000000    0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.400557    0.479696    0.552978
# SN_Kick_Magnitude_Random_Number(2)    0.359523    0.315555    0.708695
# SemiMajorAxis@ZAMS                    0.908365    0.860484   10.797558
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       7.000000   13.000000   11.000000
# Stellar_Type(2)                       1.000000    1.000000   11.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    1.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636014059  1636014060
# CE_Alpha                              1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000
# Error                                 0.000000    0.000000
# LBV_Factor                            1.500000    1.500000
# Mass@ZAMS(1)                         13.355399    5.794545
# Mass@ZAMS(2)                         10.087551    0.478302
# Merger                                0.000000    0.000000
# Merger_At_Birth                       0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.986336    0.091974
# SN_Kick_Magnitude_Random_Number(2)    0.431156    0.639741
# SemiMajorAxis@ZAMS                  270.423134    0.685395
# Sigma_Kick_CCSN_BH                  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000
# Stellar_Type(1)                      13.000000   10.000000
# Stellar_Type(2)                       1.000000    0.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    0.000000
# Unbound                               1.000000    0.000000
# WR_Factor                             1.000000    1.000000
#
# [28 rows x 1001 columns]

# %% [markdown]
# ### This function takes one of the data categories as the first argument (required).
# ### It can also take a list of seeds and show the details for those, as well as a mask on the data (using the keyword, mask).

# %%
printCompasDetails(SPs, seedsOfMergers, mask=mZams1 > 10)
# Out:
# SEED                               (units)  1636013064  1636013079  \
# CE_Alpha                                 -    1.000000    1.000000
# CH_on_MS(1)                          State    0.000000    0.000000
# CH_on_MS(2)                          State    0.000000    0.000000
# Eccentricity@ZAMS                        -    0.000000    0.000000
# Equilibrated_At_Birth                Event    0.000000    0.000000
# Error                                    -    0.000000    0.000000
# LBV_Factor                               -    1.500000    1.500000
# Mass@ZAMS(1)                          Msol   19.107134   18.370195
# Mass@ZAMS(2)                          Msol   14.425355    5.267351
# Merger                               Event    1.000000    1.000000
# Merger_At_Birth                      Event    0.000000    0.000000
# Metallicity@ZAMS(1)                      -    0.014200    0.014200
# Metallicity@ZAMS(2)                      -    0.014200    0.014200
# Omega@ZAMS(1)                           Hz    0.000000    0.000000
# Omega@ZAMS(2)                           Hz    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)       -    0.026566    0.354468
# SN_Kick_Magnitude_Random_Number(2)       -    0.669016    0.666342
# SemiMajorAxis@ZAMS                      AU    0.206363    0.068562
# Sigma_Kick_CCSN_BH                  kms^-1  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  kms^-1  265.000000  265.000000
# Sigma_Kick_ECSN                     kms^-1   30.000000   30.000000
# Sigma_Kick_USSN                     kms^-1   30.000000   30.000000
# Stellar_Type(1)                          -   13.000000    1.000000
# Stellar_Type(2)                          -    7.000000    1.000000
# Stellar_Type@ZAMS(1)                     -    1.000000    1.000000
# Stellar_Type@ZAMS(2)                     -    1.000000    1.000000
# Unbound                              State    0.000000    0.000000
# WR_Factor                                -    1.000000    1.000000
#
# SEED                                1636013103  1636013113  1636013124  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         11.036375   11.368566   11.970367
# Mass@ZAMS(2)                          0.579784    9.999001    1.502813
# Merger                                1.000000    1.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.724986    0.021165    0.948542
# SN_Kick_Magnitude_Random_Number(2)    0.154104    0.718207    0.765994
# SemiMajorAxis@ZAMS                    2.373790    0.093645    0.059091
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       7.000000    7.000000    1.000000
# Stellar_Type(2)                       0.000000    7.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  0.000000    1.000000    1.000000
# Unbound                               0.000000    0.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636013130  1636013140  1636013158  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         17.829741   15.925053   22.615264
# Mass@ZAMS(2)                          7.639141    9.123612    5.257434
# Merger                                1.000000    1.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.258237    0.056709    0.589531
# SN_Kick_Magnitude_Random_Number(2)    0.707480    0.169578    0.382295
# SemiMajorAxis@ZAMS                    3.130577    1.797470    3.516210
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       7.000000    7.000000    7.000000
# Stellar_Type(2)                       1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    0.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636013165  ...  1636013932  1636013947  \
# CE_Alpha                              1.000000  ...    1.000000    1.000000
# CH_on_MS(1)                           0.000000  ...    0.000000    0.000000
# CH_on_MS(2)                           0.000000  ...    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000  ...    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000  ...    0.000000    0.000000
# Error                                 0.000000  ...    0.000000    0.000000
# LBV_Factor                            1.500000  ...    1.500000    1.500000
# Mass@ZAMS(1)                         30.303041  ...   40.012482   13.341225
# Mass@ZAMS(2)                         20.635892  ...   13.785421    1.459733
# Merger                                1.000000  ...    1.000000    1.000000
# Merger_At_Birth                       0.000000  ...    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200  ...    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200  ...    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000  ...    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000  ...    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.049353  ...    0.879619    0.715459
# SN_Kick_Magnitude_Random_Number(2)    0.269355  ...    0.094865    0.037893
# SemiMajorAxis@ZAMS                    0.335693  ...    0.223087    0.189660
# Sigma_Kick_CCSN_BH                  265.000000  ...  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  ...  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000  ...   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000  ...   30.000000   30.000000
# Stellar_Type(1)                      13.000000  ...    1.000000    7.000000
# Stellar_Type(2)                       7.000000  ...    1.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000  ...    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000  ...    1.000000    1.000000
# Unbound                               0.000000  ...    0.000000    0.000000
# WR_Factor                             1.000000  ...    1.000000    1.000000
#
# SEED                                1636013949  1636013958  1636013969  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         12.728724   11.446976   54.104728
# Mass@ZAMS(2)                          1.401345    0.508428   15.718595
# Merger                                1.000000    1.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.760085    0.577750    0.914081
# SN_Kick_Magnitude_Random_Number(2)    0.077057    0.715162    0.225596
# SemiMajorAxis@ZAMS                    0.158995    0.030158    0.331741
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       7.000000    1.000000    1.000000
# Stellar_Type(2)                       1.000000    0.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    0.000000    1.000000
# Unbound                               0.000000    0.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636013975  1636014024  1636014040  \
# CE_Alpha                              1.000000    1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000    0.000000
# Error                                 0.000000    0.000000    0.000000
# LBV_Factor                            1.500000    1.500000    1.500000
# Mass@ZAMS(1)                         19.578339   85.656680   56.163621
# Mass@ZAMS(2)                         15.658222    4.306017   39.170120
# Merger                                1.000000    1.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.384711    0.294249    0.722848
# SN_Kick_Magnitude_Random_Number(2)    0.665429    0.054335    0.429592
# SemiMajorAxis@ZAMS                    0.083200    3.850644    0.838637
# Sigma_Kick_CCSN_BH                  265.000000  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000   30.000000
# Stellar_Type(1)                       1.000000    7.000000   14.000000
# Stellar_Type(2)                       1.000000    1.000000    7.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000    1.000000
# Unbound                               0.000000    0.000000    0.000000
# WR_Factor                             1.000000    1.000000    1.000000
#
# SEED                                1636014048  1636014056
# CE_Alpha                              1.000000    1.000000
# CH_on_MS(1)                           0.000000    0.000000
# CH_on_MS(2)                           0.000000    0.000000
# Eccentricity@ZAMS                     0.000000    0.000000
# Equilibrated_At_Birth                 0.000000    0.000000
# Error                                 0.000000    0.000000
# LBV_Factor                            1.500000    1.500000
# Mass@ZAMS(1)                         18.634462   16.565732
# Mass@ZAMS(2)                         12.706045    4.869101
# Merger                                1.000000    1.000000
# Merger_At_Birth                       0.000000    0.000000
# Metallicity@ZAMS(1)                   0.014200    0.014200
# Metallicity@ZAMS(2)                   0.014200    0.014200
# Omega@ZAMS(1)                         0.000000    0.000000
# Omega@ZAMS(2)                         0.000000    0.000000
# SN_Kick_Magnitude_Random_Number(1)    0.140128    0.400557
# SN_Kick_Magnitude_Random_Number(2)    0.308861    0.359523
# SemiMajorAxis@ZAMS                    3.505696    0.908365
# Sigma_Kick_CCSN_BH                  265.000000  265.000000
# Sigma_Kick_CCSN_NS                  265.000000  265.000000
# Sigma_Kick_ECSN                      30.000000   30.000000
# Sigma_Kick_USSN                      30.000000   30.000000
# Stellar_Type(1)                       7.000000    7.000000
# Stellar_Type(2)                       1.000000    1.000000
# Stellar_Type@ZAMS(1)                  1.000000    1.000000
# Stellar_Type@ZAMS(2)                  1.000000    1.000000
# Unbound                               0.000000    0.000000
# WR_Factor                             1.000000    1.000000
#
# [28 rows x 105 columns]

# %% [markdown]
# ## Closing the Data
#
# Accessing a single h5file from multiple scripts is not always possible.
# With notebooks, sometimes closing the notebook is not enough to have it
# close the h5data. Therefore we recommend to close the h5file explicitly after
# the calculations are done

# %%
Data.close()

# %% [markdown]
# # 3. Rewriting HDF5 files
#
# The COMPAS simulations might be very large in data size while the actual data you need to reproduce your results could be small. Hence it might make sense to reduced the number of files and columns based on some criteria.
#
# ## Here we show how you can reduce your data. You need to decide:
#
# ### - Which data categories (or HDF5 groups) you want to include
# ### - Which seeds and parameters from each data category.

# %% [markdown]
# ## Load the Data

# %%
# Set the appropriate paths to the input and output data files
pathToDataInput = pathToH5 # use the output from the run above
pathToDataOutput = compasRootDir + '/postProcessing/Tutorial/COMPAS_Output/COMPAS_Output_reduced.h5' 

Data  = h5.File(pathToDataInput)
print("The main files I have at my disposal are:\n",list(Data.keys()))
# Out:
# The main files I have at my disposal are:
#  ['BSE_Common_Envelopes', 'BSE_Double_Compact_Objects', 'BSE_RLOF', 'BSE_Supernovae', 'BSE_System_Parameters', 'Run_Details']

# %% [markdown]
# ## Specify the data categories and parameters and columns
#
# We use dictionaries to specifically link all the entries.
#
# The columnsOfInterest dictionary maps the data categories you wish to include to their appropriate parameters of interest. The seedsOfInterest dictionary maps the data categories to a list of desired seeds. If you wish to exclude some of the systems, that can be accomplished by applying a mask onto the seeds array.

# %% [markdown]
# ### Hypothetical Example
#
# Suppose you are studying Double Neutron Star systems, and you want to know the initial parameters of both components. Suppose you are separately curious about the eccentricity of systems following a Supernova that leaves the binary intact, and you want to use the same COMPAS run to save on CPU*hours.
#
# To be safe, you should probably keep the entire BSE_System_Parameters file, which contains all of the initial system settings.
#
# To get information about only Double Neutron Stars, you will need to create a mask for them from the BSE_Double_Compact_Objects file.
#
# Information on post-SN eccentricity and whether or not the system disrupted is found in the BSE_Supernovae file.
#
# You will not need any other files. You will also want to grab the system 'SEED's column from any file, since that is the unique identifier of the binaries.

# %%
### For each data category, give a list of parameters you want to include
columnsOfInterest = {'BSE_System_Parameters':      ['All'],
                     'BSE_Double_Compact_Objects': ['All'],
                     'BSE_Supernovae':             ['SEED', 'Eccentricity']
                    }

# The seedsOfInterest are a little more involved

# %% [markdown]
# ## Select the desired seeds

# %%
### BSE_System_Parameters - keep all seeds
SPs = Data['BSE_System_Parameters']
seedsSP = SPs['SEED'][()]


### BSE_Double_Compact_Objects - keep only Double Neutron Stars
DCs = Data['BSE_Double_Compact_Objects']
seedsDC =  DCs['SEED'][()]
stellarType1   =  DCs['Stellar_Type(1)'][()]
stellarType2   =  DCs['Stellar_Type(2)'][()]

# Stellar type 13 corresponds to Neutron Stars
maskDNS        =  (stellarType1 == 13) & (stellarType2 == 13)
seedsDNS       =  seedsDC[maskDNS]


### BSE_Supernovae - keep only binaries which stay intact post-SN
SNe = Data['BSE_Supernovae']
seedsSN = SNe['SEED']
isUnbound    = SNe['Unbound'][()] == 1
isIntact     = ~isUnbound

seedsIntact  = seedsSN[isIntact]



### Create seedsOfInterest dictionary 
seedsOfInterest   = {'BSE_System_Parameters':      seedsSP,
                     'BSE_Double_Compact_Objects': seedsDNS,
                     'BSE_Supernovae':             seedsIntact
                    }


### Don't forget to close the original h5 data file
Data.close()

# %% [markdown]
# ## Call the function which creates the h5 file

# %%
rewrite_H5.reduceH5(pathToOld = pathToDataInput, pathToNew = pathToDataOutput,\
                     dictColumns=columnsOfInterest, dictSeeds=seedsOfInterest)

# %%
rewrite_H5.printAllColumnsInH5(pathToDataOutput)
# Out:
# Filename = BSE_Double_Compact_Objects
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Coalescence_Time                        b'Myr'                 1
# 	   Eccentricity@DCO                        b'-'                   1
# 	   Mass(1)                                 b'Msol'                1
# 	   Mass(2)                                 b'Msol'                1
# 	   Merges_Hubble_Time                      b'State'               1
# 	   --------------------------------------------------------------------
# 	   Recycled_NS(1)                          b'Event'               1
# 	   Recycled_NS(2)                          b'Event'               1
# 	   SEED                                    b'-'                   1
# 	   SemiMajorAxis@DCO                       b'AU'                  1
# 	   Stellar_Type(1)                         b'-'                   1
# 	   --------------------------------------------------------------------
# 	   Stellar_Type(2)                         b'-'                   1
# 	   Time                                    b'Myr'                 1
#
# Filename = BSE_Supernovae
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Eccentricity                            b'-'                   63
# 	   SEED                                    b'-'                   63
#
# Filename = BSE_System_Parameters
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   CE_Alpha                                b'-'                   1000
# 	   CH_on_MS(1)                             b'State'               1000
# 	   CH_on_MS(2)                             b'State'               1000
# 	   Eccentricity@ZAMS                       b'-'                   1000
# 	   Equilibrated_At_Birth                   b'Event'               1000
# 	   --------------------------------------------------------------------
# 	   Error                                   b'-'                   1000
# 	   LBV_Factor                              b'-'                   1000
# 	   Mass@ZAMS(1)                            b'Msol'                1000
# 	   Mass@ZAMS(2)                            b'Msol'                1000
# 	   Merger                                  b'Event'               1000
# 	   --------------------------------------------------------------------
# 	   Merger_At_Birth                         b'Event'               1000
# 	   Metallicity@ZAMS(1)                     b'-'                   1000
# 	   Metallicity@ZAMS(2)                     b'-'                   1000
# 	   Omega@ZAMS(1)                           b'Hz'                  1000
# 	   Omega@ZAMS(2)                           b'Hz'                  1000
# 	   --------------------------------------------------------------------
# 	   SEED                                    b'-'                   1000
# 	   SN_Kick_Magnitude_Random_Number(1)      b'-'                   1000
# 	   SN_Kick_Magnitude_Random_Number(2)      b'-'                   1000
# 	   SemiMajorAxis@ZAMS                      b'AU'                  1000
# 	   Sigma_Kick_CCSN_BH                      b'kms^-1'              1000
# 	   --------------------------------------------------------------------
# 	   Sigma_Kick_CCSN_NS                      b'kms^-1'              1000
# 	   Sigma_Kick_ECSN                         b'kms^-1'              1000
# 	   Sigma_Kick_USSN                         b'kms^-1'              1000
# 	   Stellar_Type(1)                         b'-'                   1000
# 	   Stellar_Type(2)                         b'-'                   1000
# 	   --------------------------------------------------------------------
# 	   Stellar_Type@ZAMS(1)                    b'-'                   1000
# 	   Stellar_Type@ZAMS(2)                    b'-'                   1000
# 	   Unbound                                 b'State'               1000
# 	   WR_Factor                               b'-'                   1000

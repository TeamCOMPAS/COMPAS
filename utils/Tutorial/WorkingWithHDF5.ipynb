# %% [markdown]
# # Introduction
#
# COMPAS simulations produce all output by default in the form of an [HDF5 file](https://www.hdfgroup.org/solutions/hdf5/), which is a compact and memory efficient, but non-human-readable data file format. In order to interact with these output files, we use the python module `h5py`.
#
# Within each file are a variety of HDF5 Groups, representing a specific common event in binary evolution, e.g Roche-Lobe Overflow or Supernovae. These are described throughout the post-processing jupyter notebooks.

# %% [markdown]
# ## Material
#
# ### [1) Producing HDF5 output ](#1.-Producing-HDF5-output)
# How to run default COMPAS and produce a simple output file.
#
# ### [2) Reading HDF5 files ](#2.-Reading-HDF5-files)
# The basics and syntax of loading an HDF5 file.
#
# ### [3) Rewriting HDF5 files ](#3.-Rewriting-HDF5-files)
# How to rewrite/reduce the HDF5 data.

# %% [markdown]
# ### For the following sections, you will need to have the following python packages installed.
# ### `numpy, h5py, pandas`

# %%
import os, sys    # for handling paths
import h5py as h5  #for handling data format

# Import COMPAS root and python script directories
compasRootDir = os.environ['COMPAS_ROOT_DIR'] 
tutorialDir = compasRootDir + '/postProcessing/Tutorial/'

# Import COMPAS specific scripts
sys.path.append(compasRootDir + 'postProcessing/PythonScripts')
import h5rewrite

# %% [markdown]
# # 1. Producing HDF5 output
#
# ## Here we show an example of how to run a basic COMPAS simulation in order to produce output in an HDF5 format. To run COMPAS, you need to set the environment variable $COMPAS_ROOT_DIR to the top level COMPAS directory. Ensure that you have compiled COMPAS, and that there is a COMPAS executable. We will store the output in the Tutorial directory for easy access later on.
#
# ## For simplicity, we will run COMPAS on all default settings except for the number of binaries produced. Here, we will run 1k binaries, which is relatively small. Later, we will look at production of double compact objects (DCOs), but these objects are sufficiently rare that in order to study them, we will need to run a simulation of ~1M binaries, but this can take some time depending on your hardware resources.
#
# ### *Note:* It is required to have some COMPAS output to complete the rest of the post-processing notebooks, but if you already have an output file, you can skip this section.

# %%
# To run terminal commands in a jupyter notebook, prepend the command with an exclamation mark
# The curly brackets here are used to input python variables into the bash command
# !COMPAS -n 1000 -o {tutorialDir}
# Out:
# COMPAS v02.24.02
# Compact Object Mergers: Population Astrophysics and Statistics
# by Team COMPAS (http://compas.science/index.html)
# A binary star simulator
#
# Start generating binaries at Fri Nov 26 16:42:15 2021
#
# 0: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 1: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 2: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 3: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 4: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 5: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 6: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 7: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 8: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 9: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 10: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 11: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 12: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 13: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 14: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 15: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 16: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 17: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 18: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 19: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 20: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 21: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 22: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 23: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 24: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 25: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 26: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 27: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 28: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 29: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 30: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 31: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 32: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 33: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 34: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 35: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 36: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 37: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 38: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 39: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 40: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 41: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 42: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 43: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 44: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 45: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 46: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 47: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 48: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 49: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 50: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 51: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 52: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 53: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 54: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 55: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 56: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 57: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 58: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 59: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 60: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 61: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 62: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 63: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 64: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 65: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 66: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 67: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 68: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 69: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 70: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 71: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 72: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 73: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 74: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 75: Allowed time exceeded: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 76: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 77: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 78: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 79: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 80: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 81: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 82: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 83: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 84: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 85: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 86: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 87: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 88: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 89: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 90: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 91: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 92: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 93: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 94: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 95: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 96: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 97: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 98: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 99: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 100: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 101: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 102: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 103: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 104: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 105: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 106: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 107: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 108: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 109: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 110: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 111: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 112: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 113: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 114: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 115: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 116: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 117: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 118: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 119: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 120: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 121: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 122: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 123: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 124: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 125: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# Evolution of current binary stopped: Double compact object
# 126: Evolution stopped: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 127: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 128: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 129: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 130: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 131: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 132: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 133: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 134: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 135: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 136: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 137: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 138: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 139: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 140: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 141: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 142: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 143: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 144: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 145: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 146: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 147: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 148: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 149: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 150: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 151: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 152: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 153: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 154: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 155: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 156: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 157: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 158: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 159: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 160: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 161: Massless Remnant formed: (Main_Sequence_>_0.7 -> Massless_Remnant) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 162: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 163: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 164: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 165: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 166: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 167: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 168: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 169: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 170: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 171: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 172: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 173: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 174: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 175: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 176: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 177: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 178: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 179: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 180: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 181: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 182: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 183: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 184: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 185: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 186: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 187: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 188: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 189: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 190: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 191: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 192: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 193: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 194: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 195: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 196: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 197: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 198: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 199: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 200: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 201: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 202: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 203: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 204: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 205: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 206: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 207: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 208: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 209: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 210: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 211: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 212: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 213: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 214: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> First_Giant_Branch)
# 215: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 216: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 217: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 218: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 219: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 220: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 221: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 222: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 223: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 224: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 225: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 226: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 227: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 228: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 229: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 230: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 231: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 232: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 233: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 234: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 235: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 236: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 237: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 238: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 239: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 240: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 241: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 242: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 243: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 244: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 245: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 246: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 247: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 248: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 249: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 250: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 251: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 252: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 253: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 254: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 255: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 256: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 257: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 258: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 259: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 260: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 261: Stars merged: (Chemically_Homogeneous -> Main_Sequence_>_0.7) + (Chemically_Homogeneous -> Main_Sequence_>_0.7)
# 262: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 263: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 264: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 265: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 266: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 267: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 268: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 269: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 270: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 271: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 272: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 273: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 274: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 275: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 276: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 277: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 278: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 279: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 280: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 281: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 282: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 283: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 284: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 285: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 286: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 287: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 288: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 289: Stars merged: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 290: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 291: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 292: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 293: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 294: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 295: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 296: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 297: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 298: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 299: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 300: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 301: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 302: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 303: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 304: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 305: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 306: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 307: Double White Dwarf: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 308: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 309: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 310: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 311: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 312: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 313: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 314: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 315: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 316: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 317: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 318: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 319: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 320: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 321: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 322: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 323: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 324: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 325: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 326: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 327: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 328: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 329: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 330: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 331: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 332: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 333: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 334: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 335: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 336: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 337: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 338: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 339: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 340: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 341: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 342: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 343: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 344: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 345: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 346: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 347: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 348: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 349: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 350: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 351: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 352: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 353: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 354: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 355: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 356: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 357: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 358: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 359: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 360: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 361: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 362: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 363: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 364: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 365: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 366: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 367: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 368: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 369: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 370: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 371: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 372: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 373: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 374: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 375: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 376: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 377: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 378: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 379: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Early_Asymptotic_Giant_Branch)
# 380: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 381: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 382: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 383: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 384: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 385: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 386: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 387: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 388: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 389: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 390: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 391: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 392: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 393: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 394: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 395: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 396: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 397: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 398: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 399: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 400: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 401: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 402: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 403: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 404: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 405: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 406: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 407: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 408: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 409: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 410: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 411: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 412: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 413: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# ...
# 864: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Core_Helium_Burning)
# 865: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 866: Allowed time exceeded: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 867: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 868: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 869: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 870: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 871: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 872: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 873: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 874: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 875: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 876: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 877: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 878: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 879: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 880: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 881: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 882: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 883: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 884: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 885: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 886: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 887: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 888: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 889: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 890: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 891: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 892: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 893: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 894: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 895: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 896: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 897: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 898: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 899: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 900: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 901: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 902: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 903: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 904: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 905: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 906: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 907: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 908: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 909: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 910: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 911: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 912: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 913: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 914: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 915: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 916: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 917: Allowed time exceeded: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 918: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 919: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 920: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 921: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 922: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 923: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 924: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 925: Unbound binary: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 926: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 927: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 928: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 929: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 930: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 931: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 932: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 933: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 934: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 935: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 936: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 937: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 938: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 939: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 940: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 941: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 942: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 943: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 944: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 945: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 946: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 947: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 948: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 949: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 950: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 951: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 952: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 953: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 954: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 955: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 956: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Hertzsprung_Gap) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 957: Stars merged: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch)
# 958: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 959: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 960: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 961: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 962: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
# 963: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 964: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Black_Hole)
# 965: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 966: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 967: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 968: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 969: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 970: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 971: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 972: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 973: Allowed time exceeded: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 974: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 975: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 976: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 977: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 978: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 979: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 980: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 981: Double White Dwarf: (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 982: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 983: Unbound binary: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Neutron_Star)
# 984: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 985: Unbound binary: (Main_Sequence_>_0.7 -> Black_Hole) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 986: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 987: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 988: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf)
# 989: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 990: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 991: Allowed time exceeded: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Oxygen-Neon_White_Dwarf)
# 992: Double White Dwarf: (Main_Sequence_>_0.7 -> Carbon-Oxygen_White_Dwarf) + (Main_Sequence_>_0.7 -> Helium_White_Dwarf)
# 993: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 994: Stars merged: (Main_Sequence_>_0.7 -> Naked_Helium_Star_Giant_Branch) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 995: Stars merged: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Naked_Helium_Star_MS)
# 996: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 997: Stars merged: (Main_Sequence_>_0.7 -> Helium_White_Dwarf) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 998: Stars merged: (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7) + (Main_Sequence_>_0.7 -> Main_Sequence_>_0.7)
# 999: Unbound binary: (Main_Sequence_>_0.7 -> Neutron_Star) + (Main_Sequence_<=_0.7 -> Main_Sequence_<=_0.7)
#
# Generated 1000 of 1000 binaries requested
#
# Simulation completed
#
# End generating binaries at Fri Nov 26 16:42:35 2021
#
# Clock time = 19.9837 CPU seconds
# Wall time  = 0000:00:19 (hhhh:mm:ss)

# %% [markdown]
# ### *Note:* This will produce output in the COMPAS_Output directory only the first time it is run. If you run this multiple times, new directories will be created as COMPAS_Output_X. Ensure that you are using the data in the desired directory.

# %% [markdown]
# ## Non-default settings can be seen by running the following in the command line

# %%
# !COMPAS --help
# Out:
# COMPAS v02.24.02
# Compact Object Mergers: Population Astrophysics and Statistics
# by Team COMPAS (http://compas.science/index.html)
# A binary star simulator
#
# Options:
# --PISN-lower-limit
#   Minimum core mass for PISN, in Msol (default = 60.000000)
# --PISN-upper-limit
#   Maximum core mass for PISN, in Msol (default = 135.000000)
# --PPI-lower-limit
#   Minimum core mass for PPI, in Msol (default = 35.000000)
# --PPI-upper-limit
#   Maximum core mass for PPI, in Msol (default = 60.000000)
# --add-options-to-sysparms
#   Add program options columns to BSE/SSE SysParms file (options: [ALWAYS, GRID, NEVER], default = GRID)
# --allow-rlof-at-birth
#   Allow binaries that have one or both stars in RLOF at birth to evolve (default = TRUE)
# --allow-touching-at-birth
#   Allow binaries that are touching at birth to evolve (default = FALSE)
# --angular-momentum-conservation-during-circularisation
#   Conserve angular momentum when binary is circularised when entering a Mass Transfer episode (default = FALSE)
# --black-hole-kicks
#   Black hole kicks relative to NS kicks (options: [FULL, REDUCED, ZERO, FALLBACK], default = FALLBACK)
# --case-BB-stability-prescription
#   Case BB/BC mass transfer stability prescription (options: [ALWAYS_STABLE, ALWAYS_STABLE_ONTO_NSBH, TREAT_AS_OTHER_MT, ALWAYS_UNSTABLE], default = ALWAYS_STABLE)
# --check-photon-tiring-limit
#   Check the photon tiring limit hasn't been exceeded by wind mass loss (default = FALSE)
# --chemically-homogeneous-evolution
#   Chemically Homogeneous Evolution (options: [NONE, OPTIMISTIC, PESSIMISTIC], default = PESSIMISTIC)
# --circularise-binary-during-mass-transfer
#   Circularise binary when it enters a Mass Transfer episode (default = TRUE)
# --common-envelope-allow-main-sequence-survive
#   Allow main sequence stars to survive common envelope evolution (default = TRUE)
# --common-envelope-alpha
#   Common Envelope efficiency alpha (default = 1.000000)
# --common-envelope-alpha-thermal
#   Defined such that lambda = alpha_th * lambda_b + (1.0 - alpha_th) * lambda_g (default = 1.000000)
# --common-envelope-lambda
#   Common Envelope lambda (default = 0.100000)
# --common-envelope-lambda-multiplier
#   Multiply lambda by some constant (default = 1.000000)
# --common-envelope-lambda-prescription
#   CE lambda prescription (options: [LAMBDA_FIXED, LAMBDA_LOVERIDGE, LAMBDA_NANJING, LAMBDA_KRUCKOW, LAMBDA_DEWI], default = LAMBDA_NANJING)
# --common-envelope-mass-accretion-constant
#   Value of mass accreted by NS/BH, in Msol, during common envelope evolution, assuming all NS/BH accrete same amount of mass (common-envelope-mass-accretion-prescription CONSTANT). Ignored otherwise (default = 0.000000)
# --common-envelope-mass-accretion-max
#   Maximum amount of mass accreted by NS/BHs, in Msol, during common envelope evolution in Msol (default = 0.100000)
# --common-envelope-mass-accretion-min
#   Minimum amount of mass accreted by NS/BHs, in Msol, during common envelope evolution in Msol (default = 0.040000)
# --common-envelope-mass-accretion-prescription
#   Assumption about whether NS/BHs can accrete mass during common envelope evolution (options: [ZERO, CONSTANT, UNIFORM, MACLEOD], default = ZERO)
# --common-envelope-recombination-energy-density
#   Recombination energy density, in erg/g (default = 15000000000000.000000)
# --common-envelope-slope-kruckow
#   Common Envelope slope for Kruckow lambda (default = -0.833333)
# --cool-wind-mass-loss-multiplier
#   Multiplicative constant for wind mass loss of cool stars (default = 1.000000)
# --debug-classes
#   Debug classes enabled (default = )
# --debug-level
#   Determines which print statements are displayed for debugging (default = 0)
# --debug-to-file
#   Write debug statements to file (default = FALSE)
# --detailed-output
#   Print detailed output to file (default = FALSE)
# --eccentricity [ -e ]
#   Eccentricity, e (default = 0.000000)
# --eccentricity-distribution
#   Initial eccentricity distribution (options: [ZERO, FLAT, THERMAL, GELLER+2013, DUQUENNOYMAYOR1991, SANA2012], default = ZERO)
# --eccentricity-max
#   Maximum eccentricity to generate (default = 1.000000)
# --eccentricity-min
#   Minimum eccentricity to generate (default = 0.000000)
# --eddington-accretion-factor
#   Multiplication factor for eddington accretion for NS & BH, i.e. >1 is super-eddington and 0. is no accretion (default = 1.000000)
# --enable-warnings
#   Display warning messages to stdout (default = FALSE)
# --envelope-state-prescription
#   Prescription for whether the envelope is radiative or convective (options: [LEGACY, HURLEY, FIXED_TEMPERATURE], default = LEGACY)
# --errors-to-file
#   Write error messages to file (default = FALSE)
# --evolve-pulsars
#   Evolve pulsars (default = FALSE)
# --evolve-unbound-systems
#   Continue evolving stars even if the binary is disrupted (default = FALSE)
# --fix-dimensionless-kick-magnitude
#   Fix dimensionless kick magnitude uk to this value (default = -1.000000, -ve values false, +ve values true)
# --fryer-supernova-engine
#   If using Fryer et al 2012 fallback prescription. (options: [DELAYED, RAPID], default = DELAYED)
# --grid
#   Grid filename (default = )
# --grid-lines-to-process
#   Specifies how many grid lines should be processed (from the start line - see grid-start-line) (default = Process to EOF)
# --grid-start-line
#   Specifies which line of the grid file is processed first (0-based) (default = 0)
# --hdf5-buffer-size
#   HDF5 file dataset IO buffer size (number of chunks, default = 1)
# --hdf5-chunk-size
#   HDF5 file dataset chunk size (number of dataset entries, default = 100000)
# --help [ -h ]
#   Print this help message
# --initial-mass
#   Initial mass (in Msol) for the star (SSE) (default = 5.000000)
# --initial-mass-1
#   Initial mass (in Msol) for the primary star (BSE) (default = 5.000000)
# --initial-mass-2
#   Initial mass (in Msol) for the secondary star (BSE) (default = 5.000000)
# --initial-mass-function [ -i ]
#   Initial mass function (options: [SALPETER, POWERLAW, UNIFORM, KROUPA], default = KROUPA)
# --initial-mass-max
#   Maximum mass (in Msol) to generate using given IMF (default = 150.000000)
# --initial-mass-min
#   Minimum mass (in Msol) to generate using given IMF (default = 5.000000)
# --initial-mass-power
#   Single power law power to generate primary mass using POWERLAW IMF (default = 0.000000)
# --kick-direction
#   Natal kick direction distribution (options: [ISOTROPIC, INPLANE, PERPENDICULAR, POWERLAW, WEDGE, POLES], default = ISOTROPIC)
# --kick-direction-power
#   Power for power law kick direction distribution (default = 0.000000 = isotropic, +ve = polar, -ve = in plane)
# --kick-magnitude
#   The magnitude of the kick velocity, in km/s, that the star receives during the a supernova (default = 0.000000)
# --kick-magnitude-1
#   The magnitude of the kick velocity, in km/s, that the primary star receives during the a supernova (default = 0.000000)
# --kick-magnitude-2
#   The magnitude of the kick velocity, in km/s, that the secondary star receives during the a supernova (default = 0.000000)
# --kick-magnitude-distribution
#   Natal kick magnitude distribution (options: [ZERO, FIXED, FLAT, MAXWELLIAN, BRAYELDRIDGE, MULLER2016, MULLER2016MAXWELLIAN, MULLERMANDEL], default = MAXWELLIAN)
# --kick-magnitude-max
#   Maximum drawn kick magnitude in km/s. Ignored if < 0. Must be > 0 if using kick-magnitude-distribution=FLAT (default = -1.000000)
# --kick-magnitude-random
#   Number used to choose the kick velocity magnitude for the star during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-random-1
#   Number used to choose the kick velocity magnitude for the primary star during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-random-2
#   Number used to choose the kick velocity magnitude for the secondary during the a supernova (default = uniform random number [0.0, 1.0))
# --kick-magnitude-sigma-CCSN-BH
#   Sigma for chosen kick magnitude distribution, in km/s, for black holes (default = 265.000000)
# --kick-magnitude-sigma-CCSN-NS
#   Sigma for chosen kick magnitude distribution, in km/s, for neutron stars (default = 265.000000)
# --kick-magnitude-sigma-ECSN
#   Sigma for chosen kick magnitude distribution, in km/s, for ECSN (default = 30.000000)
# --kick-magnitude-sigma-USSN
#   Sigma for chosen kick magnitude distribution, in km/s, for USSN (default = 30.000000)
# --kick-mean-anomaly-1
#   Mean anomaly, in rad, for the primary star at instantaneous time of the supernova (default = uniform random number [0.0, 2pi))
# --kick-mean-anomaly-2
#   Mean anomaly, in rad, for the secondary star at instantaneous time of the supernova (default = uniform random number [0.0, 2pi))
# --kick-phi-1
#   Planar angle, in rad, of the supernova vector, for the primary star (default = drawn from kick direction distribution)
# --kick-phi-2
#   Planar angle, in rad, of the supernova vector, for the secondary star (default = drawn from kick direction distribution)
# --kick-scaling-factor
#   Arbitrary factor used to scale kicks (default = 1.000000)
# --kick-theta-1
#   Polar angle, in rad, of the supernova vector, for the primary star (default = drawn from kick direction distribution)
# --kick-theta-2
#   Polar angle, in rad, of the supernova vector, for the secondary star (default = drawn from kick direction distribution)
# --log-classes
#   Logging classes enabled (default = )
# --log-level
#   Determines which print statements are included in the logfile (default = 0)
# --logfile-common-envelopes
#   Filename for BSE Common Envelopes logfile (default = BSE_Common_Envelopes)
# --logfile-definitions
#   Filename for logfile record definitions (default = )
# --logfile-detailed-output
#   Filename for BSE Detailed Output logfile (default = BSE_Detailed_Output)
# --logfile-double-compact-objects
#   Filename for Double Compact Objects logfile (default = BSE_Double_Compact_Objects)
# --logfile-name-prefix
#   Prefix for logfile names (default = )
# --logfile-pulsar-evolution
#   Filename for Pulsar Evolution logfile (default = BSE_Pulsar_Evolution)
# --logfile-rlof-parameters
#   Filename for BSE RLOF Parameters logfile ( default = BSE_RLOF)
# --logfile-supernovae
#   Filename for Supernovae logfile (default = BSE_Supernovae)
# --logfile-switch-log
#   Filename for Switch Log logfile (default = BSE_Switch_Log)
# --logfile-system-parameters
#   Filename for System Parameters logfile (default = BSE_System_Parameters)
# --logfile-type
#   File type for logfiles (options: [HDF5, CSV, TSV, TXT], default = HDF5)
# --luminous-blue-variable-multiplier
#   Multiplicitive constant for LBV mass loss (default = 1.500000, use 10 for Mennekens & Vanbeveren 2014)
# --luminous-blue-variable-prescription
#   LBV Mass loss prescription (options: [NONE, HURLEY_ADD, HURLEY, BELCZYNSKI], default = HURLEY_ADD)
# --mass-loss-prescription
#   Mass loss prescription (options: [NONE, HURLEY, VINK], default = VINK)
# --mass-ratio [ -q ]
#   Mass ratio m2/m1 used to determine secondary mass if not specified (default = 1.000000)
# --mass-ratio-distribution
#   Initial mass ratio distribution for q=m2/m1 (options: [FLAT, DUQUENNOYMAYOR1991, SANA2012], default = FLAT)
# --mass-ratio-max
#   Maximum mass ratio m2/m1 to generate (default = 1.000000)
# --mass-ratio-min
#   Minimum mass ratio m2/m1 to generate (default = 0.010000)
# --mass-transfer
#   Enable mass transfer (default = TRUE)
# --mass-transfer-accretion-efficiency-prescription
#   Mass Transfer Accretion Efficiency prescription (options: [THERMAL, FIXED], default = THERMAL)
# --mass-transfer-angular-momentum-loss-prescription
#   Mass Transfer Angular Momentum Loss prescription (options: [JEANS, ISOTROPIC, CIRCUMBINARY, ARBITRARY], default = ISOTROPIC)
# --mass-transfer-fa
#   Mass Transfer fraction accreted in FIXED prescription (default = 0.500000, fully conservative)
# --mass-transfer-jloss
#   Fraction of specific angular momentum which non-accreted matter removes from the system (default = 1.000000)
# --mass-transfer-rejuvenation-prescription
#   Mass Transfer Rejuvenation prescription (options: [NONE, STARTRACK], default = STARTRACK)
# --mass-transfer-thermal-limit-C
#   Mass Transfer Thermal rate factor of the accretor (default = 10.000000)
# --mass-transfer-thermal-limit-accretor
#   Mass Transfer Thermal Accretion limit (options: [CFACTOR, ROCHELOBE], default = CFACTOR)
# --maximum-evolution-time
#   Maximum time to evolve binaries, in Myr (default = 13700.000000)
# --maximum-mass-donor-nandez-ivanova
#   Maximum donor mass, in Msol, allowed for the revised common envelope formalism in Msol (default = 2.000000)
# --maximum-neutron-star-mass
#   Maximum mass of a neutron star, in Msol (default = 2.500000)
# --maximum-number-timestep-iterations
#   Maximum number of timesteps to evolve binary before giving up (default = 99999)
# --mcbur1
#   Minimum core mass at BAGB, in Msol, to avoid fully degenerate CO core  (default = 1.600000)
# --metallicity [ -z ]
#   Metallicity to use (default 0.014200)
# --metallicity-distribution
#   Metallicity distribution (options: [ZSOLAR, LOGUNIFORM], default = ZSOLAR)
# --metallicity-max
#   Maximum metallicity to generate (default = 0.030000)
# --metallicity-min
#   Minimum metallicity to generate (default = 0.000100)
# --minimum-secondary-mass
#   Minimum mass of secondary to generate, in Msol (default = 0.100000)
# --mode
#   Evolution mode (options: [SSE, BSE], default = BSE)
# --muller-mandel-kick-multiplier-BH
#   Scaling prefactor for BH kicks when using the 'MULLERMANDEL' kick magnitude distribution (default = 200.000000)
# --muller-mandel-kick-multiplier-NS
#   Scaling prefactor for NS kicks when using the 'MULLERMANDEL' kick magnitude distribution (default = 400.000000)
# --neutrino-mass-loss-BH-formation
#   Assumption about neutrino mass loss during BH formation (options: [FIXED_FRACTION, FIXED_MASS], default = FIXED_MASS)
# --neutrino-mass-loss-BH-formation-value
#   Amount of BH mass lost due to neutrinos (either fraction or fixed value, depending on --neutrino-mass-loss-BH-formation) (default = 0.100000)
# --neutron-star-equation-of-state
#   Neutron star equation of state to use (options: [SSE, ARP3], default = SSE)
# --number-of-systems [ -n ]
#   Specify the number of systems to simulate (SSE) (default = 10)
# --orbital-period
#   Initial orbital period, in days (default = 0.100000)
# --orbital-period-distribution
#   Initial orbital period distribution (options: [FLATINLOG], default = FLATINLOG)
# --orbital-period-max
#   Maximum period, in days, to generate (default = 1000.000000)
# --orbital-period-min
#   Minimum period, in days, to generate (default = 1.100000)
# --output-container [ -c ]
#   Container (directory) name for output files (default = COMPAS_Output)
# --output-path [ -o ]
#   Directory for output (default = .)
# --overall-wind-mass-loss-multiplier
#   Multiplicitive constant for overall wind mass loss (default = 1.000000)
# --pair-instability-supernovae
#   Enable pair instability supernovae (PISN) (default = TRUE)
# --population-data-printing
#   Print details of population (default = FALSE)
# --print-bool-as-string
#   Print boolean properties as 'TRUE' or 'FALSE' (default = FALSE)
# --pulsar-birth-magnetic-field-distribution
#   Pulsar Birth Magnetic Field distribution (options: [ZERO, FIXED, FLATINLOG, UNIFORM, LOGNORMAL], default = ZERO)
# --pulsar-birth-magnetic-field-distribution-max
#   Maximum pulsar birth magnetic field, in log10(Gauss) (default = 13.000000)
# --pulsar-birth-magnetic-field-distribution-min
#   Minimum pulsar birth magnetic field, in log10(Gauss) (default = 11.000000)
# --pulsar-birth-spin-period-distribution
#   Pulsar Birth Spin Period distribution (options: [ZERO, FIXED, UNIFORM, NORMAL], default = ZERO)
# --pulsar-birth-spin-period-distribution-max
#   Maximum pulsar birth spin period, in ms (default = 100.000000)
# --pulsar-birth-spin-period-distribution-min
#   Minimum pulsar birth spin period, in ms (default = 10.000000)
# --pulsar-magnetic-field-decay-massscale
#   Mass scale on which magnetic field decays during accretion, in Msol (default = 0.025000)
# --pulsar-magnetic-field-decay-timescale
#   Timescale on which magnetic field decays, in Myrs (default = 1000.000000)
# --pulsar-minimum-magnetic-field
#   Minimum pulsar magnetic field, in log10(Gauss) (default = 8.000000)
# --pulsational-pair-instability
#   Enable mass loss due to pulsational-pair-instability (PPI) (default = TRUE)
# --pulsational-pair-instability-prescription
#   Pulsational Pair Instability prescription (options: [COMPAS, STARTRACK, MARCHANT, FARMER], default = MARCHANT)
# --quiet
#   Suppress printing (default = FALSE)
# --random-seed
#   Random seed to use (default = 0)
# --remnant-mass-prescription
#   Choose remnant mass prescription (options: [HURLEY2000, BELCZYNSKI2002, FRYER2012, MULLER2016, MULLERMANDEL, SCHNEIDER2020, SCHNEIDER2020ALT], default = FRYER2012)
# --revised-energy-formalism-nandez-ivanova
#   Enable revised energy formalism (default = FALSE)
# --rlof-printing
#   Enable output parameters before/after RLOF (default = TRUE)
# --rotational-frequency
#   Initial rotational frequency for the star for SSE (Hz) (default = 0.000000)
# --rotational-frequency-1
#   Initial rotational frequency for the primary star for BSE (Hz) (default = 0.000000)
# --rotational-frequency-2
#   Initial rotational frequency for the secondary star for BSE (Hz) (default = 0.000000)
# --rotational-velocity-distribution
#   Initial rotational velocity distribution (options: [ZERO, HURLEY, VLTFLAMES], default = ZERO)
# --semi-major-axis [ -a ]
#   Initial semi-major axis, in AU (default = 0.100000)
# --semi-major-axis-distribution
#   Initial semi-major axis distribution (options: [FLATINLOG, CUSTOM, DUQUENNOYMAYOR1991, SANA2012], default = FLATINLOG)
# --semi-major-axis-max
#   Maximum semi-major axis, in AU, to generate (default = 1000.000000)
# --semi-major-axis-min
#   Minimum semi-major axis, in AU, to generate (default = 0.010000)
# --stellar-zeta-prescription
#   Prescription for stellar zeta (default = SOBERMAN)
# --store-input-files
#   Store input files in output container (default = TRUE)
# --switch-log
#   Print switch log to file (default = FALSE)
# --timestep-multiplier
#   Timestep multiplier for SSE and BSE (default = 1.000000)
# --use-mass-loss
#   Enable mass loss (default = TRUE)
# --version [ -v ]
#   Print COMPAS version string
# --wolf-rayet-multiplier
#   Multiplicitive constant for WR winds (default = 1.000000)
# --zeta-adiabatic-arbitrary
#   Value of mass-radius exponent zeta adiabatic (default = 10000.000000)
# --zeta-main-sequence
#   Value of mass-radius exponent zeta on the main sequence (default = 2.000000)
# --zeta-radiative-envelope-giant
#   Value of mass-radius exponent zeta for radiative envelope giants (default = 6.500000)

# %% [markdown]
# # 2. Reading HDF5 files
#
# ## Here we show the basic h5 file syntax for how to load and close the file, and extract/inspect the data.
#
# While working with this notebook, feel free to change the data file used to see how it affects the output. For the purpose of consistency and ensuring that our examples work properly, the default data file `'COMPAS_Output_tutorial.h5'` has been pre-run using precisely chosen input parameters, specified in `'tutorial_grid.txt'`.
#
# If the default data file is accidentally deleted, it can be reconstructed by running:
#
# `COMPAS --grid tutorial_grid.txt`

# %% [markdown]
# ## Load the h5 file

# %%
# Set the appropriate path to the data file

pathToH5 = tutorialDir + 'COMPAS_Tutorial_Output.h5' 
Data  = h5.File(pathToH5)

# %% [markdown]
# ## Inspect the data

# %%
list(Data.keys())
# Out:
# ['BSE_Common_Envelopes',
#  'BSE_Double_Compact_Objects',
#  'BSE_RLOF',
#  'BSE_Supernovae',
#  'BSE_System_Parameters',
#  'Run_Details']

# %% [markdown]
# The list of output here depends on your simulation. Here you may see 'BSE_System_Parameters', which collects all of the information of the systems at the beginning of the evolution, as well as other major events such as 'BSE_RLOF' for all mass transfer events, 'BSE_Common_Envelopes' for all unstable mass transfer events, 'BSE_Supernovae' if you have sufficiently massive stars to undergo a supernova event, and 'BSE_Double_Compact_Objects' if you happen to form any intact binaries composed of either neutron stars or black holes (though this is quite rare and may require a large simulation).
#
# Running Single Stellar Evolution (SSE) will produce generally different outputs to Binary Stellar Evolution (BSE), but both will create a Run_Details file, which captures all of the input settings.

# %% [markdown]
# ### To show all the parameters in a given file

# %%
# It is a pain to write the entire group each time so we define shorthands
SPs = Data['BSE_System_Parameters']
list(SPs.keys())
# Out:
# ['Add_Options_To_SysParms',
#  'Allow_MS_To_Survive_CE',
#  'Allow_RLOF@Birth',
#  'Allow_Touching@Birth',
#  'BB_Mass_xFer_Stblty_Prscrptn',
#  'BH_Kicks',
#  'CE_Alpha',
#  'CE_Alpha_Thermal',
#  'CE_Lambda',
#  'CE_Lambda_Multiplier',
#  'CE_Lambda_Prscrptn',
#  'CE_Mass_Accr_Constant',
#  'CE_Mass_Accr_Max',
#  'CE_Mass_Accr_Min',
#  'CE_Mass_Accr_Prscrptn',
#  'CE_Recomb_Enrgy_Dnsty',
#  'CE_Slope_Kruckow',
#  'CHE_Mode',
#  'CH_on_MS(1)',
#  'CH_on_MS(2)',
#  'Check_Photon_Tiring_Limit',
#  'Circularise@MT',
#  'Conserve_AngMom@Circ',
#  'Cool_WindMassLoss_Multipl',
#  'Eccentricity',
#  'Eccentricity@ZAMS',
#  'Eccentricity_Dstrbtn',
#  'Eccentricity_Dstrbtn_Max',
#  'Eccentricity_Dstrbtn_Min',
#  'Eddington_Accr_Factor',
#  'Envelope_State_Prscrptn',
#  'Equilibrated_At_Birth',
#  'Error',
#  'Evolution_Mode',
#  'Fryer_SN_Engine',
#  'Initial_Mass',
#  'Initial_Mass(1)',
#  'Initial_Mass(2)',
#  'Initial_Mass_Func_Max',
#  'Initial_Mass_Func_Min',
#  'Initial_Mass_Func_Power',
#  'Initial_Mass_Function',
#  'Kick_Direction_Dstrbtn',
#  'Kick_Direction_Power',
#  'Kick_Magnitude',
#  'Kick_Magnitude(1)',
#  'Kick_Magnitude(2)',
#  'Kick_Magnitude_Dstrbtn',
#  'Kick_Magnitude_Dstrbtn_Max',
#  'Kick_Magnitude_Random',
#  'Kick_Magnitude_Random(1)',
#  'Kick_Magnitude_Random(2)',
#  'Kick_Mean_Anomaly(1)',
#  'Kick_Mean_Anomaly(2)',
#  'Kick_Phi(1)',
#  'Kick_Phi(2)',
#  'Kick_Scaling_Factor',
#  'Kick_Theta(1)',
#  'Kick_Theta(2)',
#  'LBV_Factor',
#  'LBV_Mass_Loss_Prscrptn',
#  'MCBUR1',
#  'MM_Kick_Multiplier_BH',
#  'MM_Kick_Multiplier_NS',
#  'MT_Acc_Efficiency_Prscrptn',
#  'MT_AngMom_Loss_Prscrptn',
#  'MT_Fraction_Accreted',
#  'MT_JLoss',
#  'MT_Rejuvenation_Prscrptn',
#  'MT_Thermal_Limit_C',
#  'MT_Thermally_Lmtd_Variation',
#  'Mass@ZAMS(1)',
#  'Mass@ZAMS(2)',
#  'Mass_Loss_Prscrptn',
#  'Mass_Ratio',
#  'Mass_Ratio_Dstrbtn',
#  'Mass_Ratio_Dstrbtn_Max',
#  'Mass_Ratio_Dstrbtn_Min',
#  'Max_Donor_Mass',
#  'Max_Evolution_Time',
#  'Max_NS_Mass',
#  'Max_Timesteps',
#  'Merger',
#  'Merger_At_Birth',
#  'Metallicity',
#  'Metallicity@ZAMS(1)',
#  'Metallicity@ZAMS(2)',
#  'Metallicity_Dstrbtn',
#  'Metallicity_Dstrbtn_Max',
#  'Metallicity_Dstrbtn_Min',
#  'Min_Secondary_Mass',
#  'NS_EOS',
#  'Neutrino_Mass_Loss_Assmptn',
#  'Neutrino_Mass_Loss_Value',
#  'Omega@ZAMS(1)',
#  'Omega@ZAMS(2)',
#  'Orbital_Period',
#  'Orbital_Period_Dstrbtn',
#  'Orbital_Period_Max',
#  'Orbital_Period_Min',
#  'Overall_WindMassLoss_Multipl',
#  'PISN_Lower_Limit',
#  'PISN_Upper_Limit',
#  'PPI_Lower_Limit',
#  'PPI_Prscrptn',
#  'PPI_Upper_Limit',
#  'Pulsar_Mag_Field_Decay_mScale',
#  'Pulsar_Mag_Field_Decay_tScale',
#  'Pulsar_Mag_Field_Dstrbtn',
#  'Pulsar_Mag_Field_Dstrbtn_Max',
#  'Pulsar_Mag_Field_Dstrbtn_Min',
#  'Pulsar_Minimum_Mag_Field',
#  'Pulsar_Spin_Period_Dstrbtn',
#  'Pulsar_Spin_Period_Dstrbtn_Max',
#  'Pulsar_Spin_Period_Dstrbtn_Min',
#  'Remnant_Mass_Prscrptn',
#  'Rotational_Frequency',
#  'Rotational_Frequency(1)',
#  'Rotational_Frequency(2)',
#  'Rotational_Velocity_Dstrbtn',
#  'SEED',
#  'SEED(CMDLINE)',
#  'SEED(OPTION)',
#  'SN_Kick_Magnitude_Random_Number(1)',
#  'SN_Kick_Magnitude_Random_Number(2)',
#  'Semi-Major_Axis',
#  'Semi-Major_Axis_Dstrbtn',
#  'Semi-Major_Axis_Dstrbtn_Max',
#  'Semi-Major_Axis_Dstrbtn_Min',
#  'Semi-Major_Axis_Dstrbtn_Power',
#  'SemiMajorAxis@ZAMS',
#  'Sigma_Kick_CCSN_BH',
#  'Sigma_Kick_CCSN_NS',
#  'Sigma_Kick_ECSN',
#  'Sigma_Kick_USSN',
#  'Stellar_Type(1)',
#  'Stellar_Type(2)',
#  'Stellar_Type@ZAMS(1)',
#  'Stellar_Type@ZAMS(2)',
#  'Stellar_Zeta_Prscrptn',
#  'Unbound',
#  'WR_Factor',
#  'Zeta_Adiabatic_Arbitrary',
#  'Zeta_Main_Sequence',
#  'Zeta_Radiative_Envelope_Giant']

# %% [markdown]
# ### To find the unit of a single parameter

# %%
print(SPs['Mass@ZAMS(1)'].attrs['units']) # attrs refers to attributes
# Out:
# b'Msol'

# %% [markdown]
# ### To access the values of a column

# %%
#Giving me the actual array
mZams1 = SPs['Mass@ZAMS(1)'][()]
print(mZams1.shape)                   # number of systems in this file
print(mZams1[:3])                    # the values of the first 3 entries
# Out:
# (5,)
# [ 12.703562  76.555207 113.445902]

# %% [markdown]
# ## Closing the Data
#
# Accessing a single h5file from multiple scripts is not always possible.
# With notebooks, sometimes closing the notebook is not enough to have it
# close the h5data. Therefore we recommend to close the h5file explicitly after
# the calculations are done

# %%
Data.close()

# %% [markdown]
# # 3. Rewriting HDF5 files
#
# The COMPAS simulations might be very large in data size while the actual data you need to reproduce your results could be small. Hence it might make sense to reduced the number of files and columns based on some criteria.
#
# ## Here we show how you can reduce your data. You need to decide:
#
# ### - Which data categories (or HDF5 groups) you want to include
# ### - Which seeds and parameters from each data category.

# %% [markdown]
# ## Load the Data

# %%
# Set the appropriate paths to the input and output data files
pathToDataInput = pathToH5 # use the output from the run above
pathToDataOutput = tutorialDir + '/COMPAS_Output/COMPAS_Output_reduced.h5' 

Data  = h5.File(pathToDataInput)
print("The main files I have at my disposal are:\n",list(Data.keys()))
# Out:
# The main files I have at my disposal are:
#  ['BSE_Common_Envelopes', 'BSE_Double_Compact_Objects', 'BSE_RLOF', 'BSE_Supernovae', 'BSE_System_Parameters', 'Run_Details']

# %% [markdown]
# ## Specify the data categories and parameters and columns
#
# We use dictionaries to specifically link all the entries.
#
# The columnsOfInterest dictionary maps the data categories you wish to include to their appropriate parameters of interest. The seedsOfInterest dictionary maps the data categories to a list of desired seeds. If you wish to exclude some of the systems, that can be accomplished by applying a mask onto the seeds array.

# %% [markdown]
# ### Hypothetical Example
#
# Suppose you are studying Double Neutron Star systems, and you want to know the initial parameters of both components. Suppose you are separately curious about the eccentricity of systems following a Supernova that leaves the binary intact, and you want to use the same COMPAS run to save on CPU*hours.
#
# To be safe, you should probably keep the entire BSE_System_Parameters file, which contains all of the initial system settings.
#
# To get information about only Double Neutron Stars, you will need to create a mask for them from the BSE_Double_Compact_Objects file.
#
# Information on post-SN eccentricity and whether or not the system disrupted is found in the BSE_Supernovae file.
#
# You will not need any other files. You will also want to grab the system 'SEED's column from any file, since that is the unique identifier of the binaries.

# %%
### For each data category, give a list of parameters you want to include
columnsOfInterest = {'BSE_System_Parameters':      ['All'],
                     'BSE_Double_Compact_Objects': ['All'],
                     'BSE_Supernovae':             ['SEED', 'Eccentricity']
                    }

# The seedsOfInterest are a little more involved

# %% [markdown]
# ## Select the desired seeds

# %%
### BSE_System_Parameters - keep all seeds
SPs = Data['BSE_System_Parameters']
seedsSP = SPs['SEED'][()]


### BSE_Double_Compact_Objects - keep only Double Neutron Stars
DCs = Data['BSE_Double_Compact_Objects']
seedsDC =  DCs['SEED'][()]
stellarType1   =  DCs['Stellar_Type(1)'][()]
stellarType2   =  DCs['Stellar_Type(2)'][()]

# Stellar type 13 corresponds to Neutron Stars
maskDNS        =  (stellarType1 == 13) & (stellarType2 == 13)
seedsDNS       =  seedsDC[maskDNS]


### BSE_Supernovae - keep only binaries which stay intact post-SN
SNe = Data['BSE_Supernovae']
seedsSN = SNe['SEED']
isUnbound    = SNe['Unbound'][()] == 1
isIntact     = ~isUnbound

seedsIntact  = seedsSN[isIntact]



### Create seedsOfInterest dictionary 
seedsOfInterest   = {'BSE_System_Parameters':      seedsSP,
                     'BSE_Double_Compact_Objects': seedsDNS,
                     'BSE_Supernovae':             seedsIntact
                    }


### Don't forget to close the original h5 data file
Data.close()

# %% [markdown]
# ## Call the function which creates the h5 file

# %%
h5rewrite.reduceH5(pathToOld = pathToDataInput, pathToNew = pathToDataOutput,\
                     dictColumns=columnsOfInterest, dictSeeds=seedsOfInterest)

h5rewrite.printAllColumnsInH5(pathToDataOutput)
# Out:
# Filename = BSE_Double_Compact_Objects
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Coalescence_Time                        b'Myr'                 2
# 	   Eccentricity@DCO                        b'-'                   2
# 	   Mass(1)                                 b'Msol'                2
# 	   Mass(2)                                 b'Msol'                2
# 	   Merges_Hubble_Time                      b'State'               2
# 	   --------------------------------------------------------------------
# 	   Recycled_NS(1)                          b'Event'               2
# 	   Recycled_NS(2)                          b'Event'               2
# 	   SEED                                    b'-'                   2
# 	   SemiMajorAxis@DCO                       b'AU'                  2
# 	   Stellar_Type(1)                         b'-'                   2
# 	   --------------------------------------------------------------------
# 	   Stellar_Type(2)                         b'-'                   2
# 	   Time                                    b'Myr'                 2
#
# Filename = BSE_Supernovae
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Eccentricity                            b'-'                   9
# 	   SEED                                    b'-'                   9
#
# Filename = BSE_System_Parameters
# ----------------------
# 	   column name                             unit                length
# 	   --------------------------------------------------------------------
# 	   Add_Options_To_SysParms                 b'-'                   5
# 	   Allow_MS_To_Survive_CE                  b'Flag'                5
# 	   Allow_RLOF@Birth                        b'Flag'                5
# 	   Allow_Touching@Birth                    b'Flag'                5
# 	   BB_Mass_xFer_Stblty_Prscrptn            b'-'                   5
# 	   --------------------------------------------------------------------
# 	   BH_Kicks                                b'-'                   5
# 	   CE_Alpha                                b'-'                   5
# 	   CE_Alpha_Thermal                        b'-'                   5
# 	   CE_Lambda                               b'-'                   5
# 	   CE_Lambda_Multiplier                    b'-'                   5
# 	   --------------------------------------------------------------------
# 	   CE_Lambda_Prscrptn                      b'-'                   5
# 	   CE_Mass_Accr_Constant                   b'-'                   5
# 	   CE_Mass_Accr_Max                        b'Msol'                5
# 	   CE_Mass_Accr_Min                        b'Msol'                5
# 	   CE_Mass_Accr_Prscrptn                   b'-'                   5
# 	   --------------------------------------------------------------------
# 	   CE_Recomb_Enrgy_Dnsty                   b'erg g^-1'            5
# 	   CE_Slope_Kruckow                        b'-'                   5
# 	   CHE_Mode                                b'-'                   5
# 	   CH_on_MS(1)                             b'State'               5
# 	   CH_on_MS(2)                             b'State'               5
# 	   --------------------------------------------------------------------
# 	   Check_Photon_Tiring_Limit               b'Flag'                5
# 	   Circularise@MT                          b'Flag'                5
# 	   Conserve_AngMom@Circ                    b'Flag'                5
# 	   Cool_WindMassLoss_Multipl               b'-'                   5
# 	   Eccentricity                            b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Eccentricity@ZAMS                       b'-'                   5
# 	   Eccentricity_Dstrbtn                    b'-'                   5
# 	   Eccentricity_Dstrbtn_Max                b'-'                   5
# 	   Eccentricity_Dstrbtn_Min                b'-'                   5
# 	   Eddington_Accr_Factor                   b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Envelope_State_Prscrptn                 b'-'                   5
# 	   Equilibrated_At_Birth                   b'Event'               5
# 	   Error                                   b'-'                   5
# 	   Evolution_Mode                          b'Mode'                5
# 	   Fryer_SN_Engine                         b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Initial_Mass                            b'Msol'                5
# 	   Initial_Mass(1)                         b'Msol'                5
# 	   Initial_Mass(2)                         b'Msol'                5
# 	   Initial_Mass_Func_Max                   b'Msol'                5
# 	   Initial_Mass_Func_Min                   b'Msol'                5
# 	   --------------------------------------------------------------------
# 	   Initial_Mass_Func_Power                 b'-'                   5
# 	   Initial_Mass_Function                   b'-'                   5
# 	   Kick_Direction_Dstrbtn                  b'-'                   5
# 	   Kick_Direction_Power                    b'-'                   5
# 	   Kick_Magnitude                          b'kms^-1'              5
# 	   --------------------------------------------------------------------
# 	   Kick_Magnitude(1)                       b'kms^-1'              5
# 	   Kick_Magnitude(2)                       b'kms^-1'              5
# 	   Kick_Magnitude_Dstrbtn                  b'-'                   5
# 	   Kick_Magnitude_Dstrbtn_Max              b'-'                   5
# 	   Kick_Magnitude_Random                   b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Kick_Magnitude_Random(1)                b'-'                   5
# 	   Kick_Magnitude_Random(2)                b'-'                   5
# 	   Kick_Mean_Anomaly(1)                    b'-'                   5
# 	   Kick_Mean_Anomaly(2)                    b'-'                   5
# 	   Kick_Phi(1)                             b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Kick_Phi(2)                             b'-'                   5
# 	   Kick_Scaling_Factor                     b'-'                   5
# 	   Kick_Theta(1)                           b'-'                   5
# 	   Kick_Theta(2)                           b'-'                   5
# 	   LBV_Factor                              b'-'                   5
# 	   --------------------------------------------------------------------
# 	   LBV_Mass_Loss_Prscrptn                  b'-'                   5
# 	   MCBUR1                                  b'Msol'                5
# 	   MM_Kick_Multiplier_BH                   b'-'                   5
# 	   MM_Kick_Multiplier_NS                   b'-'                   5
# 	   MT_Acc_Efficiency_Prscrptn              b'-'                   5
# 	   --------------------------------------------------------------------
# 	   MT_AngMom_Loss_Prscrptn                 b'-'                   5
# 	   MT_Fraction_Accreted                    b'-'                   5
# 	   MT_JLoss                                b'-'                   5
# 	   MT_Rejuvenation_Prscrptn                b'-'                   5
# 	   MT_Thermal_Limit_C                      b'-'                   5
# 	   --------------------------------------------------------------------
# 	   MT_Thermally_Lmtd_Variation             b'-'                   5
# 	   Mass@ZAMS(1)                            b'Msol'                5
# 	   Mass@ZAMS(2)                            b'Msol'                5
# 	   Mass_Loss_Prscrptn                      b'-'                   5
# 	   Mass_Ratio                              b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Mass_Ratio_Dstrbtn                      b'-'                   5
# 	   Mass_Ratio_Dstrbtn_Max                  b'-'                   5
# 	   Mass_Ratio_Dstrbtn_Min                  b'-'                   5
# 	   Max_Donor_Mass                          b'Msol'                5
# 	   Max_Evolution_Time                      b'Myr'                 5
# 	   --------------------------------------------------------------------
# 	   Max_NS_Mass                             b'Msol'                5
# 	   Max_Timesteps                           b'Count'               5
# 	   Merger                                  b'Event'               5
# 	   Merger_At_Birth                         b'Event'               5
# 	   Metallicity                             b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Metallicity@ZAMS(1)                     b'-'                   5
# 	   Metallicity@ZAMS(2)                     b'-'                   5
# 	   Metallicity_Dstrbtn                     b'-'                   5
# 	   Metallicity_Dstrbtn_Max                 b'-'                   5
# 	   Metallicity_Dstrbtn_Min                 b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Min_Secondary_Mass                      b'Msol'                5
# 	   NS_EOS                                  b'-'                   5
# 	   Neutrino_Mass_Loss_Assmptn              b'-'                   5
# 	   Neutrino_Mass_Loss_Value                b'-'                   5
# 	   Omega@ZAMS(1)                           b'Hz'                  5
# 	   --------------------------------------------------------------------
# 	   Omega@ZAMS(2)                           b'Hz'                  5
# 	   Orbital_Period                          b'days'                5
# 	   Orbital_Period_Dstrbtn                  b'-'                   5
# 	   Orbital_Period_Max                      b'days'                5
# 	   Orbital_Period_Min                      b'days'                5
# 	   --------------------------------------------------------------------
# 	   Overall_WindMassLoss_Multipl            b'-'                   5
# 	   PISN_Lower_Limit                        b'Msol'                5
# 	   PISN_Upper_Limit                        b'Msol'                5
# 	   PPI_Lower_Limit                         b'Msol'                5
# 	   PPI_Prscrptn                            b'-'                   5
# 	   --------------------------------------------------------------------
# 	   PPI_Upper_Limit                         b'Msol'                5
# 	   Pulsar_Mag_Field_Decay_mScale           b'Msol'                5
# 	   Pulsar_Mag_Field_Decay_tScale           b'Myr'                 5
# 	   Pulsar_Mag_Field_Dstrbtn                b'-'                   5
# 	   Pulsar_Mag_Field_Dstrbtn_Max            b'AU'                  5
# 	   --------------------------------------------------------------------
# 	   Pulsar_Mag_Field_Dstrbtn_Min            b'AU'                  5
# 	   Pulsar_Minimum_Mag_Field                b'Gauss'               5
# 	   Pulsar_Spin_Period_Dstrbtn              b'-'                   5
# 	   Pulsar_Spin_Period_Dstrbtn_Max          b'AU'                  5
# 	   Pulsar_Spin_Period_Dstrbtn_Min          b'AU'                  5
# 	   --------------------------------------------------------------------
# 	   Remnant_Mass_Prscrptn                   b'-'                   5
# 	   Rotational_Frequency                    b'Hz'                  5
# 	   Rotational_Frequency(1)                 b'Hz'                  5
# 	   Rotational_Frequency(2)                 b'Hz'                  5
# 	   Rotational_Velocity_Dstrbtn             b'-'                   5
# 	   --------------------------------------------------------------------
# 	   SEED                                    b'-'                   5
# 	   SEED(CMDLINE)                           b'-'                   5
# 	   SEED(OPTION)                            b'-'                   5
# 	   SN_Kick_Magnitude_Random_Number(1)      b'-'                   5
# 	   SN_Kick_Magnitude_Random_Number(2)      b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Semi-Major_Axis                         b'AU'                  5
# 	   Semi-Major_Axis_Dstrbtn                 b'-'                   5
# 	   Semi-Major_Axis_Dstrbtn_Max             b'AU'                  5
# 	   Semi-Major_Axis_Dstrbtn_Min             b'AU'                  5
# 	   Semi-Major_Axis_Dstrbtn_Power           b'-'                   5
# 	   --------------------------------------------------------------------
# 	   SemiMajorAxis@ZAMS                      b'AU'                  5
# 	   Sigma_Kick_CCSN_BH                      b'kms^-1'              5
# 	   Sigma_Kick_CCSN_NS                      b'kms^-1'              5
# 	   Sigma_Kick_ECSN                         b'kms^-1'              5
# 	   Sigma_Kick_USSN                         b'kms^-1'              5
# 	   --------------------------------------------------------------------
# 	   Stellar_Type(1)                         b'-'                   5
# 	   Stellar_Type(2)                         b'-'                   5
# 	   Stellar_Type@ZAMS(1)                    b'-'                   5
# 	   Stellar_Type@ZAMS(2)                    b'-'                   5
# 	   Stellar_Zeta_Prscrptn                   b'-'                   5
# 	   --------------------------------------------------------------------
# 	   Unbound                                 b'State'               5
# 	   WR_Factor                               b'-'                   5
# 	   Zeta_Adiabatic_Arbitrary                b'-'                   5
# 	   Zeta_Main_Sequence                      b'-'                   5
# 	   Zeta_Radiative_Envelope_Giant           b'-'                   5
# 	   --------------------------------------------------------------------
